# %% [markdown]
# # Get adjectives related to male and female

# %%
import numpy as np
from itertools import combinations, filterfalse
from sklearn.metrics.pairwise import cosine_similarity
from gensim.models.keyedvectors import KeyedVectors
import pandas as pd
import random
import sys
import os
import pickle

import pandas as pd
from pandas.core import indexing
from gender_predictor.GenderClassifier import classify_gender
from collections import defaultdict
from tqdm.notebook import tqdm
import multiprocessing as mp
import json

# %%
movie_data = pd.read_csv('movie.metadata.tsv', sep='\t', skip_blank_lines=True, header=None, names=['id', 'free_id', 'movie_name', 'release_date', 'revenue', 'runtime', 'languages', 'countries', 'genres'])

# %%
character = pd.read_csv('character.metadata.tsv', sep='\t', skip_blank_lines=True, header=None, names=['id', 'free_id', 'release_date','char_name', 'dob', 'gender', 'height', 'ethnicity', 'name', 'age', 'free_char_id1', 'free_char_id2', 'free_char_id3'])
character = character[['id', 'char_name', 'gender']]

# %%
movie_data['release_year'] = movie_data['release_date'].apply(lambda r:r[:4] if str(r)!='nan' else None)

# %%
movie_id_by_year = {'United States of America':{}, 'India':{}}

for index, row in movie_data.iterrows():
    for key, value in json.loads(row['countries']).items():            
        if value == 'United States of America' or value == 'India':
            if row['release_year'] not in movie_id_by_year[value]:
                movie_id_by_year[value][row['release_year']] = [row.id]
            else:
                movie_id_by_year[value][row['release_year']].append(row.id)

# %%
count = [i for i in movie_id_by_year['India'].keys() if i is not None and i<'2000']

# %%
decade_2000 = []
for c in count:
    decade_2000 += movie_id_by_year['India'][c]

# %%
len(decade_2000)
# Out:
# 4443

# %%
female_words = ['she', 'her', 'woman', 'women', 'ladies', 'girls', 'lady', 'aunt', 'grandmother', 'female', 'girl', 'damsel', 'maiden', 'daughter', 'sister', 'mother']
male_words   = ['he', 'his', 'man', 'male', 'men', 'boys', 'gentleman', 'uncle', 'grandfather', 'gentlemen', 'boy', 'bloke', 'brother', 'father']


def read_input_file(filename):
    data_df = pd.read_csv(filename,sep=',', skip_blank_lines=True, index_col= False)
    return data_df


def get_plots_by_movie_id(data_df):
    movie_ids = data_df.movie_id.unique() 
    grouped = data_df.groupby(data_df.movie_id)

    all_movie_plots = []
    for id in movie_ids:
        sents_df = grouped.get_group(id)
        all_movie_plots.append(sents_df)
    return all_movie_plots


def get_frequency_for_movie(movie):
    
    if movie.iloc[0]['movie_id'] not in decade_2000:
        return
    
    frequency_list = {'M':defaultdict(int), 'F':defaultdict(int)}
    name_data  = movie[((movie.dep_pos == 'NNP') & (movie.dep_ner == 'PERSON')) | (movie.dependent.isin(female_words)) | (movie.dependent.isin(male_words))]
    char_list  = character[character.id==movie.iloc[0]['movie_id']]
    
    gender_list = {}
    for idx,name in name_data.iterrows():            
        try:
            character_name = name['dependent'].lower()
            gender = None
            if character_name in gender_list:
                gender = gender_list[character_name]
            elif character_name in female_words:
                gender = 'F'
            elif character_name in male_words:
                gender = 'M'
            else:
                for ix, char in char_list.iterrows():
                    chk = str(char['char_name'])
                    if character_name in chk.lower():
                        gender = char['gender']
                        break
                    
                if gender is None:
                    gender = classify_gender(character_name)
                    
            gender_list[character_name] = gender
            governor = int(name['governor'])
            governor_df = movie[(movie['sentence_id']==name['sentence_id']) & (movie['token_id'] == governor) & (movie['dep_pos'].isin(['VB', 'VBP', 'VBZ', 'VBN']))]
            df2 = movie[(movie['sentence_id']==name['sentence_id']) & (movie['governor'] == name['token_id'])  & (movie['dep_pos'].isin(['VB', 'VBP', 'VBZ', 'VBN']))]
            df3 = movie[(movie['sentence_id'] == name['sentence_id']) & (movie['governor']==name['governor']) & (movie['dep_pos'].isin(['VB', 'VBP', 'VBZ', 'VBN']))]
            y = pd.concat([governor_df, df2, df3]).drop_duplicates()
            for i, x in y.iterrows():
                frequency_list[gender][x['dependent']] +=1
        except Exception as exc:
            pass
    print(movie.iloc[0]['movie_id'])
    print(frequency_list)
    return frequency_list
    
def get_name_and_adjective_mapping(all_movie_plots):
    frequency_list = {'M':defaultdict(int), 'F':defaultdict(int)}
    pool = mp.Pool(20)
    results = [pool.apply_async(get_frequency_for_movie, args=(movie,)) for movie in all_movie_plots]    
    output = [p.get() for p in results]
    return output


def get_adjective_cloud(filename):
    movie_data_df = read_input_file(filename)
    all_movie_plots = get_plots_by_movie_id(movie_data_df)
    name_adj_cluster_list = get_name_and_adjective_mapping(all_movie_plots)
    return name_adj_cluster_list

# %%
# %time result = get_adjective_cloud('india_lemma.csv')
# Out:
# Accuracy: 0.968247
# Accuracy: 0.971214
# Accuracy: 0.970121Accuracy: 0.969340
# Accuracy: 0.971162
# Accuracy: 0.969497
#
# Accuracy: 0.970486Accuracy: 0.969445
#
# Accuracy: 0.968820Accuracy: 0.967623
#
# Accuracy: 0.969393Accuracy: 0.966894
#
# Accuracy: 0.96850832345990
# Accuracy: 0.970642
# Accuracy: 0.969236
#
# Accuracy: 0.970329{'M': defaultdict(<class 'int'>, {'see': 2, 'decide': 1, 'do': 1, 'end': 1, 'approve': 1, 'know': 1}), 'F': defaultdict(<class 'int'>, {'turn': 1, 'spoil': 1, 'conceit': 1, 'attract': 1, 'complicate': 1, 'be': 1, 'see': 1, 'sing': 2})}
#
# Accuracy: 0.970382
# Accuracy: 0.970069
# Accuracy: 0.969757
# Accuracy: 0.968820
# 10594195
# {'M': defaultdict(<class 'int'>, {'be': 2, 'reveal': 2, 'go': 2, 'have': 2, 'turn': 1, 'encounter': 1, 'accompany': 1, 'reconstruct': 1}), 'F': defaultdict(<class 'int'>, {'be': 3, 'live': 1, 'have': 1, 'call': 1, 'spoil': 1, 'accustom': 1, 'surround': 1, 'accompany': 1, 'recognize': 1, 'do': 1, 'come': 1, 'know': 1, 'reconstruct': 1})}
# 5181423
# {'M': defaultdict(<class 'int'>, {'be': 1, 'have': 2, 'love': 2, 'like': 3, 'marry': 1, 'want': 1, 'establish': 1, 'think': 2, 'involve': 1, 'join': 2, 'get': 2}), 'F': defaultdict(<class 'int'>, {'have': 1, 'love': 2})}
# Accuracy: 0.969236
# Accuracy: 0.969913
# Accuracy: 0.972620
# Accuracy: 0.969236Accuracy: 0.970277
#
# Accuracy: 0.969288
# Accuracy: 0.9699659678161
#
# {'M': defaultdict(<class 'int'>, {'get': 2, 's': 1, 'kill': 2}), 'F': defaultdict(<class 'int'>, {'get': 1, 'kill': 1, 'be': 1, 'lose': 1})}
# Accuracy: 0.969705Accuracy: 0.968091
#
# Accuracy: 0.968091
# Accuracy: 0.971214Accuracy: 0.968716
# Accuracy: 0.969028
#
# Accuracy: 0.970069
# Accuracy: 0.969445Accuracy: 0.968924
#
# Accuracy: 0.969757
# Accuracy: 0.969393
# 33559533
# Accuracy: 0.970694
# {'M': defaultdict(<class 'int'>, {'try': 1, 'work': 2, 'discover': 1, 'meet': 1, 'unearth': 1}), 'F': defaultdict(<class 'int'>, {'claim': 1})}
# 11448183
# {'M': defaultdict(<class 'int'>, {'marry': 4, 'take': 2, 'have': 3, 'look': 1, 'hate': 1, 'fail': 2, 'convince': 1, 'get': 3, 'bring': 1, 'inform': 2, 'ask': 1, 'arrange': 1, 'reject': 2, 'be': 4, 'hire': 1, 'know': 2, 'do': 1, 'claim': 2}), 'F': defaultdict(<class 'int'>, {'prefer': 1, 'name': 3, 'hate': 1, 'marry': 2, 'give': 2, 'thrill': 1, 'announce': 1, 'like': 1, 'approve': 1, 'ask': 1, 'do': 1, 'act': 1})}
# 40588356488515
#
# {'M': defaultdict(<class 'int'>, {'beg': 1, 'toss': 1, 'reject': 1, 'take': 1, 'end': 1, 'like': 1, 'do': 1, 'run': 3, 'be': 1, 'come': 1, 'see': 1, 'fall': 1}), 'F': defaultdict(<class 'int'>, {'leave': 2, 'be': 5, 'die': 2, 'force': 1, 'beg': 1, 'teach': 1, 'lead': 1, 'find': 1, 'arrest': 2, 'take': 1, 'slap': 1, 'drop': 2, 'rush': 1, 'adopt': 1, 'mope': 2, 'come': 2, 'have': 2, 'onboard': 1, 'run': 1, 'say': 1, 'see': 1, 'unite': 1})}
# {'M': defaultdict(<class 'int'>, {'suffer': 1, 'hear': 1, 'meet': 2, 'pay': 1, 'ask': 1, 'marry': 1, 'discover': 1, 'think': 1, 'cheat': 1, 'force': 1, 'disown': 1, 'spend': 1, 'find': 2, 'suspect': 1, 'refuse': 1, 'come': 1, 'build': 1, 'realize': 1, 'be': 2, 'save': 1}), 'F': defaultdict(<class 'int'>, {'live': 1, 'keep': 1, 'hide': 1, 'meet': 2, 'marry': 2, 'disown': 1, 'cheat': 1, 'force': 1, 'decide': 1, 'spend': 1, 'be': 1, 'suspect': 1, 'find': 1, 'refuse': 1, 'save': 1})}
# 1072373
# {'M': defaultdict(<class 'int'>, {'lose': 1, 'boast': 1, 'happen': 1, 'meet': 1, 'go': 1, 'take': 2, 'fall': 1, 'become': 2, 'confess': 1, 'reveal': 1, 'realize': 1, 'convince': 1, 'marry': 2, 'lead': 2}), 'F': defaultdict(<class 'int'>, {'lose': 1, 'be': 2, 'establish': 1, 'see': 1, 'take': 1})}
# Accuracy: 0.970173
# 2262277
# {'M': defaultdict(<class 'int'>, {'set': 2, 'take': 2, 'tell': 2, 'come': 2, 'earn': 2, 'pay': 1, 'agree': 1, 'find': 3, 'ask': 1, 'run': 1, 'pack': 1, 'decide': 1, 'turn': 1, 'travel': 1, 'arrive': 1, 'rob': 3, 'be': 2, 'follow': 1, 'befriend': 1, 'end': 1, 'get': 4, 'learn': 1, 'need': 1, 'return': 1, 'have': 1, 'make': 1, 'attempt': 1, 'catch': 1, 'lose': 1, 'work': 1, 'feed': 1, 'live': 1, 'apprehend': 1, 'escape': 1, 'go': 1}), 'F': defaultdict(<class 'int'>, {'take': 1, 'tell': 1, 'repay': 1, 'name': 1})}
# Accuracy: 0.967727
# Accuracy: 0.969497
# Accuracy: 0.969757
# Accuracy: 0.970798
# Accuracy: 0.969861
# Accuracy: 0.970121
# Accuracy: 0.969809Accuracy: 0.969757
#
# 20904045
# Accuracy: 0.970902{'M': defaultdict(<class 'int'>, {'run': 1, 'meet': 1, 'know': 2, 'affix': 1, 'get': 1, 'prove': 1, 'marry': 1}), 'F': defaultdict(<class 'int'>, {'have': 1, 'want': 1, 'run': 1, 'catch': 1, 'come': 1, 'live': 1, 'struggle': 1, 'leave': 2})}
#
# Accuracy: 0.969445Accuracy: 0.967779Accuracy: 0.968820
#
#
# Accuracy: 0.970486
# Accuracy: 0.970069
# Accuracy: 0.968976
# Accuracy: 0.970225
# Accuracy: 0.969705
# Accuracy: 0.967362
# Accuracy: 0.968195
# Accuracy: 0.968664
# Accuracy: 0.968820
# Accuracy: 0.969028
# Accuracy: 0.969861
# Accuracy: 0.96939321038272
#
# {'M': defaultdict(<class 'int'>, {'separate': 1, 'join': 1, 'find': 1, 's': 1, 'desert': 2, 'have': 1}), 'F': defaultdict(<class 'int'>, {'move': 1, 'have': 1, 'marry': 1, 'work': 1, 'come': 1, 'know': 1, 'find': 1})}
# Accuracy: 0.969653
# Accuracy: 0.970746
# Accuracy: 0.971423Accuracy: 0.968612
# Accuracy: 0.968039
#
# Accuracy: 0.968768
# Accuracy: 0.969028Accuracy: 0.969757
#
# Accuracy: 0.969288
# Accuracy: 0.970486
# Accuracy: 0.970329
# Accuracy: 0.968976
# Accuracy: 0.969080
# Accuracy: 0.969705
# Accuracy: 0.969445
# 24282238
# {'M': defaultdict(<class 'int'>, {'don': 2, 'dream': 2, 'assassinate': 2, 'decide': 1, 'start': 1, 'refuse': 2, 'change': 2, 'obsess': 1, 'be': 1, 'pursue': 1, 'try': 2, 'repent': 1, 'become': 1}), 'F': defaultdict(<class 'int'>, {})}
# Accuracy: 0.968039
# Accuracy: 0.968039
# Accuracy: 0.970017
# Accuracy: 0.970746
# Accuracy: 0.969809
# Accuracy: 0.968924
# Accuracy: 0.969393
# Accuracy: 0.970486
# Accuracy: 0.967571
# Accuracy: 0.96897629024029
#
# {'M': defaultdict(<class 'int'>, {'fall': 1, 'oppose': 1, 'want': 1, 'marry': 1}), 'F': defaultdict(<class 'int'>, {})}
# Accuracy: 0.971110
# Accuracy: 0.970538
# Accuracy: 0.971319Accuracy: 0.969184
#
# Accuracy: 0.970486
# Accuracy: 0.971266
# Accuracy: 0.971943
# Accuracy: 0.970382
# Accuracy: 0.968091
# 22145673
# {'M': defaultdict(<class 'int'>, {'disown': 1, 'evict': 1, 'encourage': 1, 'make': 1, 'discuss': 1, 'advice': 1, 'marry': 1, 'fail': 1}), 'F': defaultdict(<class 'int'>, {'have': 1, 'be': 3, 'construe': 1, 'overcome': 1, 'disown': 1, 'evict': 1, 'move': 1, 'employ': 1, 'get': 2, 'grow': 1, 'live': 1, 'assume': 1, 'muster': 1, 'realize': 1, 'marry': 1, 'force': 1, 'convince': 1})}
# 9889964
# {'M': defaultdict(<class 'int'>, {'catch': 1, 'think': 1, 'be': 6, 'do': 1, 'see': 2, 'hear': 1, 'refuse': 1, 'arrive': 1, 'have': 3, 'run': 1, 'spend': 1, 'resist': 1, 'introduce': 1, 'kick': 1, 'become': 1, 'want': 1, 'rescue': 2, 'find': 1, 'return': 1}), 'F': defaultdict(<class 'int'>, {'see': 1, 'hear': 1, 'beat': 1, 'protect': 1, 'trick': 1, 'be': 2, 'force': 1, 'look': 1, 'get': 1, 'give': 1, 'take': 1, 'believe': 1})}
# Accuracy: 0.971735
# 295285348743599
#
# {'M': defaultdict(<class 'int'>, {'get': 1, 'meet': 1, 'know': 3, 'be': 7, 'agree': 1, 'continue': 2, 'fall': 1, 'take': 2, 'come': 2, 'decide': 1, 'do': 1, 'respond': 1, 'have': 1, 'marry': 1, 'discourage': 1, 'help': 1, 'grow': 2, 'keep': 2, 'write': 1}), 'F': defaultdict(<class 'int'>, {'live': 2, 'be': 4, 'talent': 1, 'meet': 2, 'have': 2, 'struggle': 1, 'educate': 1, 'fall': 1, 'learn': 1, 'come': 1, 'sponsor': 1, 'know': 2, 'do': 1, 'write': 4, 'respond': 1, 'love': 1, 'ignore': 2, 'express': 1, 'discourage': 2, 'lead': 1, 's': 1, 'keep': 1, 'get': 1, 'share': 1, 'screen': 1, 'decide': 1, 'try': 1, 'stop': 2, 'remain': 1, 'prevent': 1})}{'M': defaultdict(<class 'int'>, {'kill': 1, 'foil': 1, 'manage': 1, 'be': 6, 'turn': 1, 'impress': 1, 'promise': 1, 'fulfill': 1, 'catch': 1, 'ask': 1, 'attack': 1, 'try': 3, 'break': 1, 'start': 1, 'escape': 1, 'go': 1, 'find': 2, 'recognize': 2, 'prevent': 2, 'knock': 3}), 'F': defaultdict(<class 'int'>, {'turn': 1, 'be': 1, 'impress': 1, 'find': 2, 'recognize': 1})}
#
# Accuracy: 0.968091
# Accuracy: 0.968820
# Accuracy: 0.968560
# Accuracy: 0.968508
# Accuracy: 0.970434
# Accuracy: 0.968404
# Accuracy: 0.970329
# Accuracy: 0.968247
# 27667647
# {'M': defaultdict(<class 'int'>, {'be': 3, 'send': 1, 'meet': 2, 'attract': 1, 'take': 1, 'start': 1, 'find': 1, 'get': 1, 'go': 1, 'play': 1, 'let': 1, 'know': 1}), 'F': defaultdict(<class 'int'>, {'be': 1, 'marry': 1})}
# Accuracy: 0.967987Accuracy: 0.969393
#
# Accuracy: 0.968091
# Accuracy: 0.969705
# Accuracy: 0.970277
# Accuracy: 0.966530
# Accuracy: 0.970382
# Accuracy: 0.969288Accuracy: 0.968143
#
# Accuracy: 0.970017
# Accuracy: 0.969549
# Accuracy: 0.967571
# Accuracy: 0.969861
# Accuracy: 0.969028
# Accuracy: 0.970746
# Accuracy: 0.969288
# Accuracy: 0.966634
# Accuracy: 0.96829915858518
#
# {'M': defaultdict(<class 'int'>, {'be': 4, 'pay': 1, 'keep': 1, 'get': 1, 'turn': 1, 'agree': 2, 'play': 1, 'discover': 1, 'reveal': 1, 'find': 1, 'clear': 1}), 'F': defaultdict(<class 'int'>, {'leave': 1, 'be': 2, 'bring': 1, 'try': 2, 'get': 2, 'tell': 1, 'marry': 1, 'think': 1, 'reveal': 1, 'find': 1, 'clear': 1})}
# Accuracy: 0.969080
# 7876902Accuracy: 0.968664
#
# {'M': defaultdict(<class 'int'>, {'commit': 3, 'send': 1, 'reach': 1, 'get': 2, 'meet': 4, 'express': 1, 'fall': 1, 'show': 1, 'sentence': 1, 'be': 3, 'hang': 1, 'act': 1, 'have': 1, 'reveal': 2, 'kill': 2, 'throw': 1, 'announce': 2, 'follow': 1, 'believe': 1, 'find': 2}), 'F': defaultdict(<class 'int'>, {'have': 1, 'start': 1, 'attend': 1, 'leave': 2, 'surprise': 1, 'be': 1, 'see': 1, 'go': 1, 'act': 1, 'kill': 4, 'run': 1, 'tell': 2, 'follow': 1, 'remember': 1, 'find': 1, 'unfold': 1})}
# Accuracy: 0.969913Accuracy: 0.968664
#
# Accuracy: 0.968143
# Accuracy: 0.967415
# 113538969650057
#
# {'M': defaultdict(<class 'int'>, {'go': 1, 'live': 1, 'meet': 2, 'love': 2, 'reject': 1, 'start': 2, 'be': 1, 'get': 1, 'join': 1, 'bring': 1, 'help': 1, 'try': 1, 'kill': 1, 'protect': 1, 'save': 1, 'form': 1}), 'F': defaultdict(<class 'int'>, {'meet': 1, 'love': 2, 'reject': 1, 'start': 1, 'kill': 1, 'protect': 1, 'save': 1, 'form': 1})}{'M': defaultdict(<class 'int'>, {'live': 1, 'inform': 3, 'clear': 2, 'have': 1, 'plan': 1, 'accommodate': 4, 'be': 1}), 'F': defaultdict(<class 'int'>, {'live': 2, 'stay': 1, 'accommodate': 1, 'inform': 1, 'decide': 1, 'take': 1})}
#
# Accuracy: 0.969288
# Accuracy: 0.967519
# Accuracy: 0.968299
# Accuracy: 0.968976
# Accuracy: 0.970590
# Accuracy: 0.970382
# Accuracy: 0.969861
# Accuracy: 0.968768
# Accuracy: 0.970590
# Accuracy: 0.970642
# Accuracy: 0.970590
# Accuracy: 0.968664Accuracy: 0.968143
#
# Accuracy: 0.969497
# Accuracy: 0.968195
# Accuracy: 0.969445
# Accuracy: 0.970173
# Accuracy: 0.968508
# 26876259
# Accuracy: 0.969393
# {'M': defaultdict(<class 'int'>, {'accept': 1, 'know': 1, 'lose': 1}), 'F': defaultdict(<class 'int'>, {'accept': 1, 'commit': 1, 'lose': 1})}Accuracy: 0.968143
#
# Accuracy: 0.970121
# Accuracy: 0.970902
# Accuracy: 0.969809
# 21132951Accuracy: 0.970694
#
# {'M': defaultdict(<class 'int'>, {'mistake': 1, 'be': 3, 'arrest': 1, 'release': 1, 'explain': 2, 'have': 2, 'join': 1, 'fall': 1, 'imposter': 1, 'extort': 1, 'appear': 1, 'console': 2, 'try': 2, 'take': 1, 'refuse': 1, 'go': 1, 'decide': 1, 'show': 1, 'kill': 1}), 'F': defaultdict(<class 'int'>, {'happen': 1, 'get': 1, 'explain': 1, 'join': 1, 'fall': 1})}
# Accuracy: 0.968560
# Accuracy: 0.970434Accuracy: 0.970017
#
# Accuracy: 0.970277
# Accuracy: 0.968872
# 4966576
# {'M': defaultdict(<class 'int'>, {'get': 2, 'heat': 1, 'take': 2, 'encounter': 4, 'beat': 2, 'give': 1, 'fail': 1, 'suggest': 1, 'like': 1, 'be': 4, 'change': 1, 'own': 1, 'have': 3, 'employ': 1, 'allow': 1, 'do': 3, 'marry': 2, 'put': 1, 'create': 1, 'come': 2, 'work': 1, 's': 1, 'hope': 2, 'want': 3, 'break': 1, 'throw': 1, 'cancel': 1, 'keep': 1, 'burst': 1, 'murder': 3, 'banish': 2, 'crush': 1, 'happen': 1}), 'F': defaultdict(<class 'int'>, {'meet': 1, 'fall': 1, 'love': 1, 'reject': 1, 'want': 1, 'marry': 1, 'do': 1, 'be': 1, 'kill': 1, 'happen': 1})}
# Accuracy: 0.966998
# Accuracy: 0.967310
# Accuracy: 0.967883
# Accuracy: 0.968560
# Accuracy: 0.969653
# Accuracy: 0.968612
# 10419077
# {'M': defaultdict(<class 'int'>, {'be': 6, 'name': 3, 'grow': 1, 'move': 1, 'find': 5, 'ask': 1, 'hear': 1, 'go': 3, 'ensure': 1, 'arrest': 2, 'have': 1, 'sentence': 1, 'don': 1, 'disguise': 1, 'get': 1, 'know': 1, 'do': 1, 'make': 1, 'let': 1, 'turn': 1, 'hang': 1}), 'F': defaultdict(<class 'int'>, {'work': 1, 'come': 1, 'run': 1, 'cripple': 1})}
# Accuracy: 0.970538
# Accuracy: 0.969549
# 5378148
# Accuracy: 0.968404{'M': defaultdict(<class 'int'>, {'be': 1, 'fall': 3, 'keep': 1, 'return': 1, 'learn': 1, 'die': 2, 'have': 1, 'marry': 1, 'see': 1, 'resemble': 1, 'take': 1, 'try': 1}), 'F': defaultdict(<class 'int'>, {'return': 1, 'marry': 1, 'resemble': 2, 'discover': 2, 'buy': 1, 'change': 1, 'take': 1, 'refine': 1, 'make': 1, 'try': 1})}
#
# Accuracy: 0.971266
# Accuracy: 0.969028
# Accuracy: 0.968872
# Accuracy: 0.971839
# Accuracy: 0.967831
# Accuracy: 0.969028Accuracy: 0.968976
# Accuracy: 0.970694
#
# Accuracy: 0.970486
# 35790655
# {'M': defaultdict(<class 'int'>, {'be': 3, 'admit': 1}), 'F': defaultdict(<class 'int'>, {})}Accuracy: 0.968247
#
# 29574385
# {'M': defaultdict(<class 'int'>, {'manage': 1, 'take': 1, 'trace': 1, 'fulfill': 1, 'kill': 3, 'meet': 1, 'give': 2, 'shoot': 1, 'see': 2, 'try': 1, 'capture': 2, 'escape': 1, 'keep': 1, 'make': 1, 'surrender': 1, 'commit': 1, 'attain': 1}), 'F': defaultdict(<class 'int'>, {'commit': 3, 'go': 3, 'rape': 1, 'be': 2, 'flee': 1, 'meet': 1, 'give': 1, 'decide': 1, 'take': 1, 'escape': 1, 'catch': 1, 'develop': 1})}
# Accuracy: 0.969445
# 7334748
# {'M': defaultdict(<class 'int'>, {'be': 1, 'meet': 1, 'ask': 1, 'marry': 1, 'approve': 1, 'fall': 1, 'make': 2, 'tell': 2, 'involve': 1, 'oppose': 1, 'know': 1, 'look': 2, 'follow': 1, 'go': 1, 'find': 2, 'agree': 1, 'learn': 1}), 'F': defaultdict(<class 'int'>, {'marry': 1, 'approve': 1, 'be': 4, 'get': 1, 'tell': 1, 'fall': 1, 'meet': 3, 'decide': 2, 'adopt': 1, 'continue': 1, 'start': 1, 'receive': 1, 'lie': 1, 'follow': 1, 'call': 1, 'want': 1})}
# Accuracy: 0.969653
# Accuracy: 0.969653
# Accuracy: 0.967675
# 6471697
# {'M': defaultdict(<class 'int'>, {'seek': 1, 'usurp': 1, 'instruct': 1, 'strangle': 1, 'throw': 1, 'blame': 1, 'take': 1, 'begin': 1, 'be': 3, 'fall': 1, 'raise': 1, 'plan': 1}), 'F': defaultdict(<class 'int'>, {'present': 1, 'blind': 1, 'be': 2, 'wash': 1, 'blame': 1, 'take': 1, 'begin': 1, 'woo': 1})}
# 26431639
# {'M': defaultdict(<class 'int'>, {'make': 1, 'try': 1, 'win': 1}), 'F': defaultdict(<class 'int'>, {'identify': 1, 'be': 1, 'hate': 1, 'marry': 1})}
# Accuracy: 0.968299
# Accuracy: 0.968820
# Accuracy: 0.968976
# Accuracy: 0.969340
# Accuracy: 0.969861
# Accuracy: 0.967727
# Accuracy: 0.969705
# 32151115
# {'M': defaultdict(<class 'int'>, {'be': 1, 'believe': 1, 'convince': 1, 'reunite': 1}), 'F': defaultdict(<class 'int'>, {'love': 1, 'be': 7, 'believe': 1, 'disappear': 1, 'try': 1, 'convince': 2, 'have': 2, 'find': 1, 'die': 2})}
# Accuracy: 0.968820
# Accuracy: 0.967415
# Accuracy: 0.968404
# Accuracy: 0.970590
# Accuracy: 0.969445
# Accuracy: 0.971006
# Accuracy: 0.970277
# Accuracy: 0.968091
# Accuracy: 0.971162
# 24641171
# {'M': defaultdict(<class 'int'>, {'be': 5, 'drive': 1, 'support': 1, 'catch': 2, 'imprison': 1, 'shock': 1, 'learn': 1, 'charge': 1, 'have': 1, 'sentence': 1}), 'F': defaultdict(<class 'int'>, {})}
# Accuracy: 0.972308
# Accuracy: 0.971475
# Accuracy: 0.968872
# Accuracy: 0.969445
# Accuracy: 0.971058
# Accuracy: 0.972464
# Accuracy: 0.970017
# Accuracy: 0.970798
# Accuracy: 0.970225Accuracy: 0.967831
#
# Accuracy: 0.970382
# Accuracy: 0.968612
# Accuracy: 0.970954
# Accuracy: 0.970746
# Accuracy: 0.968768
# Accuracy: 0.969757Accuracy: 0.969913
# Accuracy: 0.972255
#
# 32098888
# {'M': defaultdict(<class 'int'>, {}), 'F': defaultdict(<class 'int'>, {'support': 1})}
# Accuracy: 0.968351
# 26013008
# {'M': defaultdict(<class 'int'>, {'try': 2, 'kidnap': 1, 'want': 1, 'see': 1, 'sentence': 2, 'execute': 1, 'be': 1, 'save': 1}), 'F': defaultdict(<class 'int'>, {'kidnap': 2, 'free': 1, 'name': 2, 'continue': 1, 'vanish': 2, 'become': 1, 'handle': 1, 'be': 3, 'reveal': 1, 'rape': 1, 'save': 1})}
# Accuracy: 0.969497
# Accuracy: 0.969236
# Accuracy: 0.969861
# 28350035
# {'M': defaultdict(<class 'int'>, {'like': 2, 'do': 1, 'promise': 1, 'commit': 1, 'run': 1, 'be': 1, 'return': 1, 'marry': 1}), 'F': defaultdict(<class 'int'>, {'be': 5, 'love': 1, 'marry': 1, 'like': 1})}
# Accuracy: 0.970329
# Accuracy: 0.969757Accuracy: 0.971006
# Accuracy: 0.968508
# Accuracy: 0.968404
# Accuracy: 0.970434
# 9633533
# {'M': defaultdict(<class 'int'>, {'convict': 2, 'escape': 1, 'land': 1, 'send': 1, 'be': 4, 'follow': 1, 'meet': 2, 'struggle': 1, 'bear': 1, 'try': 3, 'report': 1, 'fail': 3, 'befriend': 1, 'find': 1, 'nab': 1, 'reach': 1, 'love': 1, 'convince': 1, 'give': 2, 'like': 1, 'ask': 1, 'join': 1, 'bring': 1, 'see': 1, 'order': 1, 'refuse': 1, 'take': 1, 'defuse': 1}), 'F': defaultdict(<class 'int'>, {'be': 3, 'accept': 1, 'reveal': 1, 'rape': 1, 'kill': 1, 'convict': 1, 'like': 1, 'ask': 1, 'join': 2, 'let': 1, 'bring': 1, 'see': 2, 'make': 1, 'give': 1, 'decide': 1})}
# Accuracy: 0.968508
# Accuracy: 0.970590
# Accuracy: 0.967362
# Accuracy: 0.968976
# Accuracy: 0.97027730816196
#
# {'M': defaultdict(<class 'int'>, {'be': 8, 'adopt': 1, 'give': 2, 'have': 1, 'frequent': 1, 'stop': 1, 'see': 1, 'decide': 1, 'propose': 1, 'disclose': 1, 'want': 3, 'reveal': 1, 'marry': 5, 'love': 2, 'meet': 2, 'say': 1, 'forget': 1, 'arrive': 1, 'learn': 1, 'force': 2, 'stay': 1, 'start': 4, 'realize': 1, 'happen': 1}), 'F': defaultdict(<class 'int'>, {'love': 3, 'work': 1, 'be': 4, 'continue': 2, 'harbor': 1, 'live': 1, 'marry': 5, 'look': 1, 'declare': 1, 'become': 1, 'meet': 2, 'say': 2, 'talk': 1, 'lose': 1, 'feel': 1, 'apologize': 1, 'ask': 1, 'decide': 2, 'go': 1, 'forget': 1, 'join': 2, 'learn': 3, 'make': 2, 'keep': 1, 'sacrifice': 2, 'respect': 2})}
# Accuracy: 0.969236
# 8993821
# {'M': defaultdict(<class 'int'>, {'play': 4}), 'F': defaultdict(<class 'int'>, {})}
# Accuracy: 0.967675
# Accuracy: 0.969184
# Accuracy: 0.969757
# Accuracy: 0.969757
# 5392217
# Accuracy: 0.969132{'M': defaultdict(<class 'int'>, {'raise': 2, 'irk': 2, 'inform': 1, 'hire': 4, 'be': 5, 'conceal': 1, 'include': 1, 'try': 3, 'keep': 2, 'leave': 1, 'start': 2, 'make': 2, 'insist': 2, 'add': 1, 'design': 2, 'have': 3, 'see': 1, 'decide': 4, 'follow': 1, 'go': 1, 'reveal': 1, 'refuse': 1, 'work': 1, 'drop': 2, 'demand': 1, 'tell': 1, 'avoid': 1, 'sing': 1, 'woo': 1, 'find': 1, 'manage': 1, 'convince': 1, 'relent': 1, 'build': 1}), 'F': defaultdict(<class 'int'>, {'have': 1, 'say': 1, 'bother': 1, 'hide': 1, 'go': 1, 'get': 1, 'come': 1, 'demand': 1, 'know': 1, 'tell': 1, 'start': 1, 'avoid': 1, 'woo': 1, 'be': 1})}
#
# Accuracy: 0.968820
# Accuracy: 0.969705
# Accuracy: 0.970694
# Accuracy: 0.971735
# Accuracy: 0.969965
# Accuracy: 0.970017
# 23703779
# {'M': defaultdict(<class 'int'>, {'be': 5, 'meet': 1, 'live': 1, 'like': 1, 'make': 3, 'believe': 3, 'befriend': 2, 'promise': 2, 'use': 1, 'obtain': 2, 'lose': 1, 'arrest': 1, 'go': 1, 'trick': 1, 'try': 2, 'flee': 1, 'catch': 4, 'defeat': 1}), 'F': defaultdict(<class 'int'>, {'like': 1, 'steal': 1, 'love': 2, 'marry': 1})}
# Accuracy: 0.970382
# Accuracy: 0.968976
# Accuracy: 0.969653
# Accuracy: 0.969809
# Accuracy: 0.968299
# Accuracy: 0.970329
# Accuracy: 0.969965
# Accuracy: 0.968872
# 2172156Accuracy: 0.969809
#
# {'M': defaultdict(<class 'int'>, {'have': 1, 'want': 1, 'share': 1, 'engage': 1, 'be': 6, 'transfer': 1, 'ramapuram': 1, 'try': 2, 'intervene': 1, 'beat': 5, 'save': 1, 'disturb': 1, 'accuse': 2, 'drag': 1, 'join': 1, 'ask': 2, 'leave': 2, 'warn': 1, 'create': 1, 'pacify': 2, 'break': 2, 'meet': 1, 'explain': 1, 'feel': 1, 'avenge': 1, 'ransack': 1, 'manhandle': 1, 'read': 1, 'cite': 1}), 'F': defaultdict(<class 'int'>, {'claim': 1, 'start': 1, 'warn': 1, 'meet': 1, 'explain': 1, 'ask': 1, 'follow': 1, 'marry': 1, 'get': 1, 'feel': 1, 'decide': 1, 'avenge': 1, 'manhandle': 1})}
# Accuracy: 0.967935
# 29865278
# Accuracy: 0.971110{'M': defaultdict(<class 'int'>, {'be': 17, 'find': 4, 'banish': 2, 'decide': 1, 'expand': 1, 'investigate': 1, 'meet': 3, 'fall': 1, 'leave': 1, 'promise': 1, 'surprise': 2, 'see': 4, 'confuse': 1, 'get': 2, 'duplicate': 5, 'tell': 5, 'prod': 1, 'think': 1, 'know': 2, 'identify': 4, 'throw': 3, 'go': 2, 'learn': 1, 'smell': 2, 'succeed': 1, 'infiltrate': 1, 'run': 1, 'arrest': 1, 'forget': 1, 'have': 5, 'escape': 1, 'stop': 1, 'explain': 4, 'come': 1, 'realize': 1, 'create': 1, 'call': 1, 'take': 1, 'reveal': 1, 'keep': 1, 'discover': 1, 'hide': 1, 'convince': 1, 'arrive': 1, 'anticipate': 1, 'lure': 1, 're-introduce': 1, 'send': 2, 'unite': 1}), 'F': defaultdict(<class 'int'>, {'be': 6, 'head': 1, 'name': 2, 'see': 2, 'think': 1, 'forget': 2, 'have': 3, 'turn': 1, 'go': 1, 'escape': 1, 'stop': 1, 'explain': 1, 'convict': 1, 'meet': 1, 'call': 2, 'come': 2, 'work': 1, 'pretend': 2, 'threaten': 1, 'expose': 1, 'show': 1, 'tell': 1, 'keep': 2, 'know': 1, 'throw': 1, 'hide': 2, 'convince': 2, 're-introduce': 1})}
#
# Accuracy: 0.96736225495137
#
# {'M': defaultdict(<class 'int'>, {'want': 1, 'kill': 1}), 'F': defaultdict(<class 'int'>, {'kill': 1, 'rescue': 1})}
# 16364045
# {'M': defaultdict(<class 'int'>, {'marry': 2, 'name': 1, 'have': 1, 'come': 1, 'work': 1, 'turn': 1, 'be': 3, 'fall': 2, 'become': 1, 'get': 1, 'bring': 3, 'refuse': 1, 'destroy': 2, 'take': 2, 'learn': 1, 're-establish': 1}), 'F': defaultdict(<class 'int'>, {'be': 3, 'marry': 1, 'have': 1, 'come': 1, 'turn': 1})}
# Accuracy: 0.968924
# Accuracy: 0.968195
# 26088981
# {'M': defaultdict(<class 'int'>, {'be': 3, 'work': 1, 'fall': 1, 'frame': 1, 'escape': 1, 'try': 1, 'discover': 1, 'find': 1, 'bring': 1, 'kill': 1}), 'F': defaultdict(<class 'int'>, {'discover': 2, 'murder': 1, 'be': 1})}
# Accuracy: 0.970173
# Accuracy: 0.967935
# Accuracy: 0.969653
# Accuracy: 0.969445
# Accuracy: 0.971943
# Accuracy: 0.969601
# Accuracy: 0.968247
# 18562918
# {'M': defaultdict(<class 'int'>, {'call': 1, 'be': 3, 'send': 1, 'commit': 1, 'happen': 1, 'find': 2, 'leave': 1, 'beat': 1, 'meet': 2, 'get': 1, 'earn': 1, 'release': 2, 'expose': 1, 'marry': 1, 'take': 1}), 'F': defaultdict(<class 'int'>, {'be': 4, 'frame': 1, 'educate': 1, 'marry': 1, 'find': 2, 'leave': 1, 'take': 2})}
# Accuracy: 0.970121Accuracy: 0.969861
#
# Accuracy: 0.968768
# Accuracy: 0.969653
# Accuracy: 0.968299
# Accuracy: 0.968872
# Accuracy: 0.968924
# Accuracy: 0.968716Accuracy: 0.969445
#
# 33606762
# {'M': defaultdict(<class 'int'>, {'help': 1}), 'F': defaultdict(<class 'int'>, {'tell': 1, 'help': 1})}
# Accuracy: 0.968039
# 7731039
# {'M': defaultdict(<class 'int'>, {'target': 1, 'want': 2, 'find': 1, 'warn': 1, 'attract': 1, 'ditch': 1, 'treat': 1, 'get': 1, 'marry': 2, 'tease': 1, 'realize': 2, 'decide': 2, 'discover': 1, 'prove': 1, 'drive': 1, 'live': 1, 'change': 1}), 'F': defaultdict(<class 'int'>, {'target': 1, 'come': 1, 'want': 1, 'marry': 3, 'find': 2, 'warn': 1, 'attract': 2, 'get': 1, 'ditch': 2, 'know': 1, 'use': 1, 'discover': 1, 'hurt': 1, 'leave': 1, 'be': 1, 'live': 1})}
# Accuracy: 0.969080
# Accuracy: 0.969132
# Accuracy: 0.971214
# Accuracy: 0.971006
# Accuracy: 0.971735
# 5008724
# {'M': defaultdict(<class 'int'>, {'betray': 1, 'be': 2, 'meet': 1, 'shock': 1, 'see': 1, 'stack': 1, 'take': 1, 'try': 1, 'marry': 2}), 'F': defaultdict(<class 'int'>, {'have': 1, 'wear': 1, 'smoke': 1, 'drink': 1, 'meet': 1, 'marry': 1, 'impress': 1, 'be': 1, 'want': 2, 'come': 1, 'see': 1, 'reject': 1, 'redeem': 1, 'give': 2, 'adopt': 1})}
# Accuracy: 0.968039
# 6795118
# {'M': defaultdict(<class 'int'>, {'fail': 1, 'demand': 2, 'pay': 1, 'abduct': 1, 'find': 1}), 'F': defaultdict(<class 'int'>, {'abduct': 1, 'happen': 1, 'be': 1, 'love': 1, 'find': 1})}
# Accuracy: 0.970694
# Accuracy: 0.969913
# 7334454
# {'M': defaultdict(<class 'int'>, {'kill': 2, 'tell': 1, 'be': 2, 'do': 2, 'bring': 1, 'remember': 2, 'make': 2, 'escape': 1, 'confront': 1, 'go': 2, 'determine': 1, 'reverse': 1, 'have': 2, 'convince': 1, 'let': 1, 'unite': 1}), 'F': defaultdict(<class 'int'>, {'enter': 1, 'fall': 1, 'look': 1, 'remember': 3, 'marry': 1, 'do': 1, 'confront': 2, 'escape': 1, 'go': 1, 'explain': 1, 'stay': 1})}
# Accuracy: 0.969445
# Accuracy: 0.969809
# 36057884
# {'M': defaultdict(<class 'int'>, {'be': 3, 'live': 1, 'send': 1, 'bear': 1, 'fall': 1, 'collect': 1, 'take': 1, 'fight': 2, 'pass': 1, 'become': 1, 'save': 2, 'accuse': 3, 'commit': 1, 'marry': 1, 'get': 1, 'decide': 2}), 'F': defaultdict(<class 'int'>, {'send': 1, 'commit': 1})}
# Accuracy: 0.968872
# Accuracy: 0.969393
# Accuracy: 0.969861
# Accuracy: 0.970538
# Accuracy: 0.969757
# 25131366
# {'M': defaultdict(<class 'int'>, {'tell': 1}), 'F': defaultdict(<class 'int'>, {'tell': 1, 'drive': 1})}
# Accuracy: 0.967519
# Accuracy: 0.969549
# Accuracy: 0.969653
# Accuracy: 0.971423
# Accuracy: 0.967883
# Accuracy: 0.970538
# Accuracy: 0.969288Accuracy: 0.968872
#
# Accuracy: 0.971683
# 26104950
# {'M': defaultdict(<class 'int'>, {'meet': 1, 'cal': 1, 'arrive': 1}), 'F': defaultdict(<class 'int'>, {'want': 1, 'marry': 2, 'love': 1, 'belong': 1, 'meet': 1, 'find': 1, 'be': 1, 'demand': 1, 'insist': 1, 'pretend': 1, 'give': 1, 'start': 1, 'arrive': 1, 'feign': 1, 'disguise': 1})}
# Accuracy: 0.970694
# Accuracy: 0.969288
# 36151270
# {'M': defaultdict(<class 'int'>, {'kill': 2, 'accumulate': 1, 'be': 1, 'end': 1, 'do': 3, 'meet': 1}), 'F': defaultdict(<class 'int'>, {'name': 1, 'protect': 1, 'accumulate': 1, 'arrest': 1, 'hold': 1, 'meet': 1, 'kill': 1})}
# Accuracy: 0.971527
# Accuracy: 0.967675
# 23758269
# {'M': defaultdict(<class 'int'>, {}), 'F': defaultdict(<class 'int'>, {'play': 1})}
# 10599593
# {'M': defaultdict(<class 'int'>, {'be': 3, 'die': 1, 'inherit': 2, 'give': 1, 'convince': 1, 'mend': 3, 'marry': 1, 'appear': 1, 'do': 1, 'involve': 1, 'introduce': 1, 'hire': 1, 'have': 1, 'act': 1, 'claim': 1, 'convict': 2}), 'F': defaultdict(<class 'int'>, {'know': 2, 'refuse': 1, 'introduce': 1, 'name': 3, 'decide': 1, 'make': 1, 'do': 1, 'be': 2, 'act': 1, 'claim': 2})}
# Accuracy: 0.969913
# Accuracy: 0.969080
# 24969779
# {'M': defaultdict(<class 'int'>, {'be': 1, 'announce': 1, 'declare': 1}), 'F': defaultdict(<class 'int'>, {'arrange': 1, 'wield': 1, 'fail': 1, 'marry': 1})}
# Accuracy: 0.967935
# Accuracy: 0.969236
# Accuracy: 0.970017Accuracy: 0.969288
#
# Accuracy: 0.968299
# Accuracy: 0.968872
# Accuracy: 0.968924
# 662746
# {'M': defaultdict(<class 'int'>, {'murder': 2, 'be': 3, 'find': 1, 'defeat': 3, 'meet': 1, 'begin': 1, 'investigate': 1}), 'F': defaultdict(<class 'int'>, {'receive': 1, 'meet': 1, 'defeat': 1, 'confide': 1, 'begin': 1, 'fall': 1, 'tell': 1})}
# Accuracy: 0.969757
# 20903033
# {'M': defaultdict(<class 'int'>, {'marry': 1, 'be': 1, 'get': 2, 'keep': 1, 'have': 1, 'find': 1}), 'F': defaultdict(<class 'int'>, {})}
# Accuracy: 0.970798
# Accuracy: 0.970538
# Accuracy: 0.969288
# Accuracy: 0.969236
# Accuracy: 0.970850
# Accuracy: 0.968872
# Accuracy: 0.968560
# 6763625
# {'M': defaultdict(<class 'int'>, {'be': 4, 'spend': 1, 'notice': 1, 'do': 2, 'try': 5, 'help': 1, 'find': 2, 'decide': 2, 'marry': 2, 'come': 2, 'see': 3, 'drink': 1, 'flirt': 1, 'talk': 1, 'want': 2, 'think': 1, 'go': 1, 'fix': 1, 'start': 1, 'calm': 1, 'arrive': 1, 'realize': 1, 'return': 1, 'tell': 2, 'ask': 2, 'threaten': 1, 'commit': 1, 'fall': 1}), 'F': defaultdict(<class 'int'>, {'dream': 1, 'become': 1, 'be': 1, 'overlook': 2, 'let': 1, 'marry': 3, 'calm': 1, 'have': 2, 'tell': 2, 'go': 1, 'fire': 1, 'ask': 1, 'accept': 2, 'do': 1, 'threaten': 1, 'make': 1})}
# Accuracy: 0.968976
# Accuracy: 0.971631
# Accuracy: 0.968976
# Accuracy: 0.971371Accuracy: 0.969445
#
# 33944586
# {'M': defaultdict(<class 'int'>, {'dedicate': 1, 'be': 4, 'respect': 1, 'erect': 1}), 'F': defaultdict(<class 'int'>, {'be': 1, 'save': 1})}
# 10636802
# {'M': defaultdict(<class 'int'>, {'widow': 1, 'marry': 1}), 'F': defaultdict(<class 'int'>, {'be': 2, 'marry': 3, 'get': 1, 'have': 1, 'become': 1, 'admit': 1, 'see': 3, 'strike': 1, 'lose': 2, 'regain': 2, 'remember': 1, 'discharge': 1, 'come': 2, 'find': 2, 'start': 1, 'experience': 1, 'feel': 1})}
# Accuracy: 0.969393
# Accuracy: 0.970694
# Accuracy: 0.969913
# Accuracy: 0.967779
# Accuracy: 0.968664
# 7235995
# {'M': defaultdict(<class 'int'>, {'intend': 1, 'have': 1, 'nurse': 1, 'make': 1}), 'F': defaultdict(<class 'int'>, {'be': 3, 'raise': 2, 'orphan': 1, 'marry': 2, 'have': 1, 'nurse': 1, 'do': 2, 'dedicate': 2, 'become': 1, 'make': 1})}
# Accuracy: 0.970902
# Accuracy: 0.966738
# Accuracy: 0.968768
# 18544488
# {'M': defaultdict(<class 'int'>, {'be': 1, 'have': 1}), 'F': defaultdict(<class 'int'>, {'have': 1, 'be': 9, 'consider': 2, 'marry': 1, 'follow': 1, 'declare': 1, 'lead': 1, 'jail': 1, 'order': 2, 'keep': 1, 'give': 1})}
# Accuracy: 0.966582Accuracy: 0.969445
#
# 25713949
# {'M': defaultdict(<class 'int'>, {'haunt': 1, 'be': 1, 'meet': 1, 'kill': 2}), 'F': defaultdict(<class 'int'>, {'meet': 1})}
# Accuracy: 0.968716Accuracy: 0.967935
#
# Accuracy: 0.970121
# 30674
# 25924200{'M': defaultdict(<class 'int'>, {'kill': 1}), 'F': defaultdict(<class 'int'>, {'name': 2, 'become': 1, 'discover': 1, 'move': 1, 'be': 1, 'question': 1, 'complete': 1})}
#
# {'M': defaultdict(<class 'int'>, {'select': 1, 'get': 1, 'give': 1, 'be': 2, 'face': 1}), 'F': defaultdict(<class 'int'>, {'love': 1})}
# Accuracy: 0.969445
# 35584608
# {'M': defaultdict(<class 'int'>, {'get': 1, 'want': 1, 'refuse': 1, 'leave': 1, 'believe': 1, 'be': 1, 'go': 1, 'lose': 1}), 'F': defaultdict(<class 'int'>, {'get': 1, 'refuse': 1, 'give': 1})}
# 8181039
# Accuracy: 0.970382
# {'M': defaultdict(<class 'int'>, {'recollect': 1, 'hurt': 2, 'be': 3, 'break': 1, 'get': 2, 'accommodate': 2, 'have': 1, 'love': 1, 'attract': 1, 'behave': 2, 'irritate': 1, 'drop': 1, 'want': 1, 'accept': 1, 'happen': 2, 'marry': 3, 'give': 1, 'convince': 2, 'provoke': 1, 'insult': 1, 'kidnap': 1, 'come': 1, 'threaten': 1, 'pull': 1, 'jump': 1, 'tolerate': 2}), 'F': defaultdict(<class 'int'>, {'name': 2, 'accommodate': 1, 'have': 3, 'do': 3, 'invite': 1, 'live': 2, 'be': 9, 'introduce': 1, 'accept': 3, 'flourish': 1, 'see': 2, 'fall': 2, 'approach': 2, 'impress': 3, 'hear': 1, 'misunderstand': 1, 'play': 1, 'attract': 3, 'get': 4, 'lie': 2, 'love': 4, 'respond': 1, 'irritate': 1, 'tell': 1, 'convince': 3, 'drop': 3, 'tolerate': 3, 'confuse': 1, 'confess': 2, 'come': 1, 'know': 1, 'ask': 1, 'want': 1, 'decide': 1, 'marry': 4, 'refuse': 1, 'explain': 1, 'insult': 1, 'save': 2, 'rescue': 1, 'pull': 1, 'jump': 1})}
# Accuracy: 0.970277
# Accuracy: 0.968924
# Accuracy: 0.968091
# Accuracy: 0.968820
# Accuracy: 0.970590
# Accuracy: 0.968143
# Accuracy: 0.969340
# Accuracy: 0.968456
# 19898489
# Accuracy: 0.968404{'M': defaultdict(<class 'int'>, {'have': 1, 'claim': 1, 'be': 1, 'forget': 1, 'tell': 2, 'accept': 2, 'love': 2}), 'F': defaultdict(<class 'int'>, {'happen': 1, 'accept': 2, 'love': 1, 'be': 1})}
#
# Accuracy: 0.970277
# Accuracy: 0.969653
# Accuracy: 0.970486
# Accuracy: 0.967467
# Accuracy: 0.969445
# Accuracy: 0.969809
# Accuracy: 0.970277
# Accuracy: 0.969549
# 4023052
# {'M': defaultdict(<class 'int'>, {'be': 7, 'despise': 1, 'suppose': 1, 'go': 7, 'decide': 2, 'tease': 1, 'get': 1, 'slap': 1, 'stop': 9, 'show': 3, 'determine': 1, 'keep': 1, 'testify': 2, 'make': 1, 'say': 1, 'pay': 3, 'lie': 2, 'separate': 2, 'think': 1, 'tell': 3, 'punish': 1, 'try': 2, 'come': 2, 'arrest': 1, 'release': 1, 'agree': 1, 'let': 1, 'set': 1, 'refuse': 1, 'leave': 2, 'convince': 1, 'do': 1, 'shut': 1, 'kill': 2, 'hurry': 1, 'ask': 1, 'realize': 1, 'have': 1, 'end': 1}), 'F': defaultdict(<class 'int'>, {'tease': 1, 'kill': 3, 'slap': 1, 'stop': 3, 'abort': 1, 'have': 1, 'be': 1, 'see': 1, 'tell': 2, 'try': 1, 'go': 1, 'plead': 1, 'leave': 1, 'agree': 1, 'do': 2, 'set': 1, 'convince': 1})}
# Accuracy: 0.970798
# Accuracy: 0.970329
# Accuracy: 0.970382
# 31384964
# {'M': defaultdict(<class 'int'>, {'be': 11, 'have': 4, 'like': 2, 'take': 4, 'attach': 1, 'die': 1, 'ask': 2, 'refuse': 1, 'try': 6, 'prove': 1, 'know': 1, 'chop': 2, 'tell': 5, 'return': 1, 'play': 1, 'accept': 1, 'ignore': 1, 'confess': 1, 'leave': 3, 'give': 1, 'arrest': 1, 'come': 1, 'release': 2, 'marry': 2, 'see': 1, 'shock': 1, 'run': 1, 'reach': 2, 'beat': 1, 'help': 1, 'find': 1, 'kill': 2}), 'F': defaultdict(<class 'int'>, {'have': 1, 'die': 1, 'steal': 1, 'do': 1, 'take': 1, 'be': 4, 'refuse': 1, 'give': 1, 'return': 1, 'play': 1, 'ignore': 1, 'try': 2, 'commit': 1, 'marry': 2, 'see': 2, 'tell': 1, 'ask': 1, 'run': 1, 'bless': 1, 'leave': 2, 'allow': 1, 'elope': 1, 'invite': 1})}
# Accuracy: 0.968560
# Accuracy: 0.968976
# 18568161
# {'M': defaultdict(<class 'int'>, {'be': 1}), 'F': defaultdict(<class 'int'>, {'be': 3, 'lose': 4, 'yearn': 1, 'love': 1, 'sit': 1, 'eat': 3, 'adopt': 1, 'sleep': 1, 'drink': 2, 'upset': 1, 'take': 1})}
# Accuracy: 0.969497
# Accuracy: 0.969757
# Accuracy: 0.968768
# Accuracy: 0.971475
# Accuracy: 0.969861
# Accuracy: 0.970954
# Accuracy: 0.969757
# 3635024
# {'M': defaultdict(<class 'int'>, {'give': 3, 'follow': 1, 'be': 5, 'want': 2, 'call': 1, 'go': 1, 'shoot': 1, 'stop': 1, 'take': 1, 'find': 1, 'impress': 1, 'kill': 3, 'build': 2, 'sell': 1, 'try': 1, 'show': 1, 'get': 2, 'know': 1, 'beat': 1, 'switch': 2, 'leave': 1}), 'F': defaultdict(<class 'int'>, {'be': 5, 'see': 1, 'impress': 2, 'notice': 2, 'do': 1, 'go': 1, 'contact': 2, 'get': 3, 'meet': 2, 'believe': 1, 'want': 1, 'find': 1, 'say': 1, 'give': 2, 'enter': 1, 'shout': 1})}
# Accuracy: 0.968351
# Accuracy: 0.969653
# Accuracy: 0.969236
# Accuracy: 0.969028
# Accuracy: 0.970538
# 25697925
# {'M': defaultdict(<class 'int'>, {'find': 2, 'marry': 1, 'expire': 1, 'stick': 1, 'support': 1, 'believe': 1, 'fall': 1, 'perform': 1}), 'F': defaultdict(<class 'int'>, {'marry': 1, 'abandon': 1, 'injure': 1, 'get': 1})}Accuracy: 0.969236
#
# Accuracy: 0.971683
# Accuracy: 0.970694
# Accuracy: 0.969132
# Accuracy: 0.970902
# Accuracy: 0.971110
# Accuracy: 0.969809
# Accuracy: 0.968508
# Accuracy: 0.969757
# Accuracy: 0.968247
# Accuracy: 0.970382
# 11353416
# {'M': defaultdict(<class 'int'>, {'carry': 1, 'turn': 1, 'die': 1, 'feel': 1, 'be': 2, 'leave': 1, 'embroil': 1, 'try': 1, 'kill': 2, 'hide': 1, 'join': 1, 'regain': 1, 'suffer': 1, 'take': 2, 'use': 1, 'smuggle': 1, 'get': 1, 'hold': 2}), 'F': defaultdict(<class 'int'>, {'save': 2, 'carry': 1, 'turn': 2, 'find': 2, 'take': 1, 'have': 1, 'blackmail': 1, 'be': 1, 'smuggle': 1, 'hold': 1})}
# Accuracy: 0.968091
# Accuracy: 0.969080
# Accuracy: 0.968612
# Accuracy: 0.970225
# Accuracy: 0.968091
# Accuracy: 0.968924
# Accuracy: 0.969497
# Accuracy: 0.967571
# Accuracy: 0.969601
# Accuracy: 0.969340
# Accuracy: 0.968560
# Accuracy: 0.969236
# 163500
# {'M': defaultdict(<class 'int'>, {'meet': 1, 'seem': 1, 'be': 2, 'lose': 1, 'take': 1}), 'F': defaultdict(<class 'int'>, {'meet': 1, 'realize': 1})}
# Accuracy: 0.969549
# Accuracy: 0.968612
# Accuracy: 0.97027714205956
#
# {'M': defaultdict(<class 'int'>, {'promote': 1, 'alia': 1, 'be': 5, 'dream': 2, 'agree': 1, 'have': 2, 'instruct': 1, 'do': 1, 'realize': 1, 'try': 2, 'break': 1, 'tell': 1}), 'F': defaultdict(<class 'int'>, {'alia': 1})}
# 10638975
# {'M': defaultdict(<class 'int'>, {'be': 5, 'send': 1, 'refuse': 1, 'lift': 1, 'court-martialle': 1, 'capture': 1, 'humiliate': 1, 'agree': 2, 'promise': 2, 'foil': 1, 'join': 1, 'make': 1}), 'F': defaultdict(<class 'int'>, {})}
# Accuracy: 0.969445
# Accuracy: 0.970173
# 3260061
# {'M': defaultdict(<class 'int'>, {'widow': 1, 'be': 1, 'fall': 1, 'stop': 1, 'give': 1, 'raise': 1, 'implicate': 1}), 'F': defaultdict(<class 'int'>, {'lend': 1, 'widow': 1, 'be': 1, 'fall': 1, 'raise': 1, 'abuse': 1, 'commit': 3})}
# Accuracy: 0.968872
# Accuracy: 0.970434
# Accuracy: 0.969809
# Accuracy: 0.971058
# Accuracy: 0.969601
# 10892704
# {'M': defaultdict(<class 'int'>, {'be': 9, 'run': 1, 'name': 2, 'expose': 2, 'come': 4, 'regard': 1, 'decide': 5, 'help': 2, 'find': 1, 'start': 4, 'try': 2, 'buy': 1, 'stand': 1, 'throw': 1, 'realize': 1, 'trump': 3, 'support': 3, 'follow': 1, 'become': 1, 'meet': 3, 'surprise': 2, 'learn': 3, 'disturb': 1, 'stop': 2, 'dismantle': 1, 'do': 3, 'confront': 2, 'accept': 1, 'tell': 2, 'mean': 2, 'confess': 1, 'give': 2, 'kidnap': 1, 'threaten': 2, 'enter': 1, 'save': 2, 'kill': 1, 'shoot': 3, 'arrest': 1, 'die': 2}), 'F': defaultdict(<class 'int'>, {'see': 1, 'try': 1, 'regard': 1, 'die': 1, 'meet': 1, 'learn': 1})}
# Accuracy: 0.968664
# Accuracy: 0.969236
# Accuracy: 0.968404
# Accuracy: 0.968976
# 15464779
# {'M': defaultdict(<class 'int'>, {'live': 1, 'know': 1, 'be': 1, 'land': 1, 'recruit': 1, 'pay': 1, 'get': 1, 'persist': 1, 'celebrate': 1, 'relieve': 1, 'investigate': 1, 'attempt': 1}), 'F': defaultdict(<class 'int'>, {})}
# Accuracy: 0.969340
# Accuracy: 0.969809
# Accuracy: 0.968195
# Accuracy: 0.969549Accuracy: 0.969965
#
# Accuracy: 0.969861
# Accuracy: 0.969861
# Accuracy: 0.968664
# Accuracy: 0.970329
# Accuracy: 0.969080
# Accuracy: 0.969288
# Accuracy: 0.972203
# Accuracy: 0.971058Accuracy: 0.969653
#
# Accuracy: 0.970225
# Accuracy: 0.971214
# Accuracy: 0.968508
# Accuracy: 0.967831
# Accuracy: 0.970329
# 5089524
# {'M': defaultdict(<class 'int'>, {'face': 1, 'orphan': 1, 'struggle': 3, 'make': 1, 'name': 3, 'like': 2, 'do': 2, 'adopt': 1, 'be': 9, 'decide': 2, 'steal': 1, 'promise': 2, 'break': 1, 'refuse': 2, 'let': 3, 'catch': 2, 'attend': 1, 'deliver': 1, 'accuse': 1, 'banish': 1, 'embrace': 1, 'find': 1, 'become': 1, 'amass': 1, 'have': 4, 'manage': 1, 'build': 1, 'forget': 1, 'get': 1, 'believe': 1, 'snub': 1, 'upset': 1, 'visit': 3, 'risk': 1, 'save': 2, 'introduce': 1, 'begin': 3, 'work': 1, 'fall': 1, 'anger': 1, 'love': 2, 'confront': 2, 'thrash': 1, 'swear': 1, 'kill': 3, 'thank': 1, 'try': 1, 'profess': 1, 'transcribe': 1, 'reciprocate': 1, 'sacrifice': 1, 'marry': 1, 'offer': 1, 'leave': 1, 'arrive': 1, 'demand': 1, 'stop': 1, 'form': 1, 'hatch': 1, 'destroy': 1, 'follow': 5, 'rescue': 2, 'kidnap': 1, 'send': 1, 'battle': 2, 'wound': 1, 'tell': 3, 'reach': 1, 'collapse': 1, 'complete': 1, 'sing': 1}), 'F': defaultdict(<class 'int'>, {'empathize': 1, 'form': 1, 'work': 1, 'decide': 1, 'die': 2, 'forget': 1, 'have': 2, 'fall': 1, 'believe': 1, 'snub': 2, 'love': 3, 'kill': 2, 'be': 6, 'discover': 1, 'go': 1, 'visit': 3, 'offer': 1, 'pay': 1, 'leave': 2, 'promise': 1, 'let': 3, 'refuse': 1, 'stop': 1, 'kidnap': 3, 'follow': 2, 'rescue': 2, 'send': 1})}
# 5534117
# {'M': defaultdict(<class 'int'>, {'capture': 1, 'realize': 2, 'slap': 1, 'do': 2, 're-shape': 2, 'kill': 1, 'have': 1, 'set': 1, 'determine': 1, 'be': 1, 'get': 1, 'recruit': 1, 'assist': 1, 'agree': 1, 'join': 1, 'enjoy': 1}), 'F': defaultdict(<class 'int'>, {'slap': 1, 'capture': 1, 'lose': 1})}
# 18849333
# Accuracy: 0.968143{'M': defaultdict(<class 'int'>, {'woo': 1, 'win': 1, 'addict': 1, 'get': 2, 'ill-treat': 1, 'desert': 1, 'proceed': 1, 'fall': 1, 'impress': 1, 'fill': 1, 'awake': 1, 'be': 1}), 'F': defaultdict(<class 'int'>, {'desert': 1, 'impress': 1})}
#
# Accuracy: 0.968924
# Accuracy: 0.971266
# Accuracy: 0.970538Accuracy: 0.969080
#
# Accuracy: 0.970329
# Accuracy: 0.970121
# 17565926
# Accuracy: 0.970746{'M': defaultdict(<class 'int'>, {'inquire': 1, 'tell': 1, 'be': 2, 'support': 1, 'decide': 2, 'marry': 1, 'injure': 1, 'force': 1, 'accept': 1, 'reunite': 1, 'help': 1, 'do': 1, 'ask': 1, 'stay': 1, 'find': 1, 'bring': 1, 'take': 1}), 'F': defaultdict(<class 'int'>, {'tell': 1, 'be': 4, 'have': 1, 'live': 1, 'sympathize': 1, 'fall': 1, 'support': 1, 'marry': 2, 'take': 1, 'get': 1, 'refuse': 2, 'decide': 2, 'force': 1, 'explain': 1, 'change': 1, 'reunite': 1, 'help': 1, 'do': 1, 'stay': 1, 'agree': 1, 'start': 1, 'find': 1, 'go': 1})}
#
# Accuracy: 0.971735
# Accuracy: 0.970538
# Accuracy: 0.970069
# Accuracy: 0.968560
# Accuracy: 0.970434
# Accuracy: 0.968820
# Accuracy: 0.971058
# Accuracy: 0.971839
# Accuracy: 0.969080Accuracy: 0.973192
#
# Accuracy: 0.969601Accuracy: 0.969080
#
# Accuracy: 0.972047
# Accuracy: 0.970225
# Accuracy: 0.967727
# Accuracy: 0.966842
# Accuracy: 0.969705
# Accuracy: 0.966530
# Accuracy: 0.970069
# Accuracy: 0.970850
# Accuracy: 0.969965
# Accuracy: 0.969601
# Accuracy: 0.969965
# Accuracy: 0.972203
# Accuracy: 0.968716
# Accuracy: 0.968456
# Accuracy: 0.969184
# 664402
# {'M': defaultdict(<class 'int'>, {'tell': 3, 'love': 4, 'do': 1, 'be': 3, 'feel': 1, 'see': 1, 'leave': 1, 'watch': 1, 'release': 1}), 'F': defaultdict(<class 'int'>, {'be': 15, 'realize': 4, 'encourage': 1, 'tell': 6, 'leave': 4, 'love': 7, 'decide': 2, 'marry': 3, 'have': 5, 'know': 3, 'write': 1, 'ask': 1, 'name': 2, 'read': 1, 'give': 1, 'engage': 3, 'explain': 1, 'do': 1, 'feel': 2, 'learn': 1, 'meet': 6, 'remember': 1, 'congratualte': 1, 'take': 1, 'watch': 1, 'bring': 1, 'go': 1, 'release': 1})}
# Accuracy: 0.969340
# Accuracy: 0.970954
# Accuracy: 0.969653
# Accuracy: 0.968143Accuracy: 0.967831
#
# Accuracy: 0.971266
# 29151231
# {'M': defaultdict(<class 'int'>, {'get': 2, 'murder': 1, 'find': 3, 'beat': 1, 'come': 1, 'regain': 2, 'assist': 1, 'have': 1, 'spend': 1, 'manage': 1, 'escape': 2, 'jump': 1, 'die': 1, 'participate': 1, 'hide': 1, 'unweave': 1}), 'F': defaultdict(<class 'int'>, {'happen': 1, 'drive': 1})}
# Accuracy: 0.969236
# Accuracy: 0.969340
# Accuracy: 0.969340
# Accuracy: 0.969549
# Accuracy: 0.968716
# 14760023
# {'M': defaultdict(<class 'int'>, {'learn': 2, 'challenge': 1, 'convince': 1, 'belong': 1}), 'F': defaultdict(<class 'int'>, {'be': 2, 'learn': 1, 'marry': 2, 'impress': 1})}
# Accuracy: 0.969809
# Accuracy: 0.971475
# Accuracy: 0.969393
# Accuracy: 0.968768
# Accuracy: 0.971371
# Accuracy: 0.969653
# Accuracy: 0.969497
# Accuracy: 0.968299
# Accuracy: 0.968560
# Accuracy: 0.970225
# 18004274
# {'M': defaultdict(<class 'int'>, {'want': 2, 'avenge': 1, 'retrieve': 1, 'set': 2, 'search': 1, 'narrate': 1, 'lure': 2, 'get': 1, 'fight': 1, 'return': 1}), 'F': defaultdict(<class 'int'>, {'send': 1, 'sacrifice': 1, 'capture': 1, 'feel': 2, 'betray': 2})}
# 21020059
# {'M': defaultdict(<class 'int'>, {'marry': 1}), 'F': defaultdict(<class 'int'>, {'marry': 1, 'agree': 1})}Accuracy: 0.969809
#
# Accuracy: 0.969757
# Accuracy: 0.970746
# Accuracy: 0.968404
# Accuracy: 0.972099
# 4036425Accuracy: 0.970017
#
# {'M': defaultdict(<class 'int'>, {'find': 2, 'win': 2, 'break': 1, 'be': 1, 'think': 1, 'manage': 1}), 'F': defaultdict(<class 'int'>, {'fall': 1})}
# Accuracy: 0.970434
# 5945009
# {'M': defaultdict(<class 'int'>, {'move': 1, 'meet': 3, 'show': 1, 'be': 4, 'try': 1, 'kill': 3, 'fall': 2, 'attempt': 1, 'get': 2, 'think': 1, 'create': 1, 'refuse': 1, 'seem': 1, 'shoot': 1, 'follow': 1, 'survive': 1, 'enter': 1, 'keep': 1, 'have': 1, 'avenge': 1, 'become': 1, 'protect': 2}), 'F': defaultdict(<class 'int'>, {'be': 1, 'elope': 1, 'marry': 1, 'meet': 1, 'fall': 1, 'take': 1, 'kill': 1})}
# Accuracy: 0.968039
# Accuracy: 0.96970510640935
#
# {'M': defaultdict(<class 'int'>, {'decide': 1, 'go': 2, 'meet': 1, 'kill': 1, 'let': 1}), 'F': defaultdict(<class 'int'>, {'bring': 1, 'be': 3, 'meet': 1, 'fall': 1})}
# Accuracy: 0.970486
# 9691493
# {'M': defaultdict(<class 'int'>, {'have': 1, 'hear': 1, 'end': 1, 'recognize': 1, 'mention': 1, 'believe': 1, 'assume': 1, 'decease': 1, 'break': 1}), 'F': defaultdict(<class 'int'>, {'belong': 1, 'prefer': 1, 'have': 1, 'throw': 1, 'meet': 1, 'recognize': 1, 'be': 3, 'urge': 2, 'consider': 1, 'decide': 1, 'spend': 2, 'begin': 1, 'look': 1, 'fill': 1, 'lament': 1, 'accept': 1, 'continue': 1, 'help': 1})}
# Accuracy: 0.970798
# Accuracy: 0.970225
# Accuracy: 0.967779
# Accuracy: 0.969601
# 10640941
# {'M': defaultdict(<class 'int'>, {'fight': 1, 'fall': 1, 'escape': 1}), 'F': defaultdict(<class 'int'>, {'arrest': 1, 'fall': 1, 'identify': 1})}
# Accuracy: 0.969184
# Accuracy: 0.970382
# Accuracy: 0.969965
# Accuracy: 0.967935
# 5249887
# {'M': defaultdict(<class 'int'>, {'have': 2, 'be': 3, 'complete': 1, 'spend': 1, 'hide': 1, 'see': 1, 'begin': 1, 'prove': 2, 'sell': 1, 'stage': 1}), 'F': defaultdict(<class 'int'>, {'have': 2, 'see': 3, 'give': 2, 'impress': 1, 'begin': 1, 'accommodate': 1, 'be': 4, 'marry': 1, 'kidnap': 1, 'lurch': 1, 'rescue': 2})}
# Accuracy: 0.969132
# Accuracy: 0.969757
# Accuracy: 0.970069
# Accuracy: 0.970277
# Accuracy: 0.968299
# Accuracy: 0.967935
# Accuracy: 0.968820
# Accuracy: 0.968872
# 5032246
# {'M': defaultdict(<class 'int'>, {'kidnap': 1}), 'F': defaultdict(<class 'int'>, {'walk': 1, 'lead': 1})}
# Accuracy: 0.967362
# Accuracy: 0.969132
# Accuracy: 0.970017
# Accuracy: 0.967050
# Accuracy: 0.967362
# Accuracy: 0.968612
# Accuracy: 0.968716Accuracy: 0.968508
#
# Accuracy: 0.969497
# Accuracy: 0.970434
# Accuracy: 0.969809Accuracy: 0.966998
#
# Accuracy: 0.968664
# Accuracy: 0.968247
# Accuracy: 0.969653
# Accuracy: 0.969445
# Accuracy: 0.96939321103650
#
# {'M': defaultdict(<class 'int'>, {'call': 1, 'leave': 1, 'dedicate': 2, 'be': 1, 'hold': 1}), 'F': defaultdict(<class 'int'>, {'be': 1})}
# Accuracy: 0.970538
# Accuracy: 0.966738Accuracy: 0.971162
#
# 24185289
# {'M': defaultdict(<class 'int'>, {'have': 1, 'keep': 3, 'take': 3, 'introduce': 1, 'accept': 1}), 'F': defaultdict(<class 'int'>, {'live': 2, 'introduce': 1, 'accept': 2, 'keep': 1})}
# Accuracy: 0.970173
# 19609512
# {'M': defaultdict(<class 'int'>, {'involve': 1, 'be': 1, 'love': 1}), 'F': defaultdict(<class 'int'>, {'start': 1, 'love': 1})}
# Accuracy: 0.968508Accuracy: 0.968976
#
# Accuracy: 0.969445
# Accuracy: 0.969861
# Accuracy: 0.969705Accuracy: 0.969288
#
# Accuracy: 0.969965
# Accuracy: 0.970902
# Accuracy: 0.967415
# 9689645
# {'M': defaultdict(<class 'int'>, {'believe': 1, 'perceive': 1}), 'F': defaultdict(<class 'int'>, {'do': 1})}
# 6768793
# {'M': defaultdict(<class 'int'>, {'be': 5, 'treat': 2, 'live': 1, 'keep': 1, 'die': 1, 'fall': 1, 'have': 1, 'show': 1, 'try': 1, 'kidnap': 2, 'fail': 1, 'call': 1, 'receive': 1, 'explain': 1, 'marry': 1}), 'F': defaultdict(<class 'int'>, {})}
# Accuracy: 0.969080
# Accuracy: 0.968612
# 25899808
# {'M': defaultdict(<class 'int'>, {'hang': 1, 'kill': 1, 'be': 2, 'meet': 1, 'worship': 1, 'revere': 1, 'inform': 1, 'agree': 1, 'save': 1, 'appoint': 1, 'wait': 1, 'decide': 1, 'help': 2, 'try': 1, 'convict': 1}), 'F': defaultdict(<class 'int'>, {})}
# Accuracy: 0.969340
# Accuracy: 0.968247
# Accuracy: 0.969861
# 21028695
# {'M': defaultdict(<class 'int'>, {'help': 1}), 'F': defaultdict(<class 'int'>, {})}
# Accuracy: 0.970225
# Accuracy: 0.970329
# Accuracy: 0.969132
# Accuracy: 0.966998
# Accuracy: 0.969288
# Accuracy: 0.969184Accuracy: 0.970069
#
# Accuracy: 0.968143
# Accuracy: 0.970590
# Accuracy: 0.970173
# Accuracy: 0.970121
# Accuracy: 0.969445
# 29830825Accuracy: 0.968091
#
# {'M': defaultdict(<class 'int'>, {'be': 1}), 'F': defaultdict(<class 'int'>, {'catch': 1, 'be': 1})}
# Accuracy: 0.967779
# Accuracy: 0.967831
# Accuracy: 0.968456
# Accuracy: 0.969549
# Accuracy: 0.968456
# Accuracy: 0.969549
# Accuracy: 0.970225Accuracy: 0.969236
#
# Accuracy: 0.968091
# Accuracy: 0.967675
# 27301153
# {'M': defaultdict(<class 'int'>, {'be': 1}), 'F': defaultdict(<class 'int'>, {})}
# Accuracy: 0.970434
# Accuracy: 0.969445
# Accuracy: 0.969809
# Accuracy: 0.968612
# 26161289
# {'M': defaultdict(<class 'int'>, {'marry': 1, 'leave': 1, 'get': 2, 'know': 1, 'defeat': 1}), 'F': defaultdict(<class 'int'>, {'want': 1, 'marry': 1, 'take': 1, 'leave': 1, 'capture': 1, 'be': 1, 'steal': 1, 'fall': 1})}
# Accuracy: 0.968508
# Accuracy: 0.970486
# 23899512
# {'M': defaultdict(<class 'int'>, {'live': 2, 'take': 1, 'leave': 1, 'lead': 1, 'grow': 1, 'have': 2, 'meet': 1, 'decide': 1, 'ditch': 1, 'join': 1, 'know': 1, 'do': 2, 'hesitate': 2, 'kill': 1}), 'F': defaultdict(<class 'int'>, {'be': 1, 'switch': 1, 'end': 1, 'take': 1, 'leave': 1, 'have': 2, 'ditch': 1, 'join': 1, 'know': 1, 'do': 1, 'hesitate': 1, 'kill': 1})}
# Accuracy: 0.972151
# Accuracy: 0.968299
# Accuracy: 0.968404
# Accuracy: 0.970329
# Accuracy: 0.971214
# Accuracy: 0.970173
# 2682493
# {'M': defaultdict(<class 'int'>, {}), 'F': defaultdict(<class 'int'>, {})}
# Accuracy: 0.969132
# Accuracy: 0.970277
# Accuracy: 0.970746
# 12332323
# {'M': defaultdict(<class 'int'>, {'have': 1, 'be': 2, 'go': 1}), 'F': defaultdict(<class 'int'>, {'be': 8, 'marry': 2, 'take': 1, 'work': 1, 'concern': 1, 'make': 1, 'dream': 1, 'have': 1})}
# Accuracy: 0.969809
# Accuracy: 0.970590
# Accuracy: 0.967987
# Accuracy: 0.969965
# Accuracy: 0.970121
# Accuracy: 0.968924Accuracy: 0.968247
#
# Accuracy: 0.971423
# Accuracy: 0.970746
# Accuracy: 0.969340
# Accuracy: 0.96809124468896
#
# {'M': defaultdict(<class 'int'>, {'work': 1, 'widow': 2, 'name': 1, 'educate': 1, 'get': 1, 'lose': 2, 'complete': 1, 'pass': 1, 'try': 1, 'devastate': 1, 'commit': 1, 'hospitalise': 2, 'be': 1, 'recover': 1}), 'F': defaultdict(<class 'int'>, {'live': 1, 'widow': 1, 'get': 3, 'marry': 2, 'ensure': 1, 'name': 4, 'grow': 1, 'have': 1, 'happen': 1, 'accuse': 2, 'leave': 1, 'be': 1})}
# Accuracy: 0.967467Accuracy: 0.970642
#
# 2909975
# ...
# Accuracy: 0.970902
# Accuracy: 0.970590
# Accuracy: 0.969497
# 35485635Accuracy: 0.969288
# {'M': defaultdict(<class 'int'>, {'be': 2, 'kill': 3, 'know': 2, 'apologize': 2, 'write': 1, 'arrest': 1, 'have': 2, 'release': 2, 'save': 1, 'reveal': 2, 'gopi': 1, 'kidnap': 3, 'manage': 1, 'escape': 1, 'prakash': 1}), 'F': defaultdict(<class 'int'>, {'be': 1, 'investigate': 1, 'write': 1, 'get': 1, 'die': 3, 'kidnap': 1})}
#
# Accuracy: 0.970121
# Accuracy: 0.971214Accuracy: 0.970225
#
# Accuracy: 0.969393
# Accuracy: 0.969757
# Accuracy: 0.968768
# Accuracy: 0.970225
# Accuracy: 0.969132
# Accuracy: 0.968143
# Accuracy: 0.970069
# Accuracy: 0.970746
# 26705987
# {'M': defaultdict(<class 'int'>, {'receive': 1, 'worship': 1, 'warn': 1, 'be': 11, 'oppose': 1, 'involve': 4, 'get': 3, 'invite': 2, 'save': 2, 'arrest': 1, 'sentence': 1, 'turn': 1, 'develop': 1, 'release': 1, 'appoint': 1, 'try': 3, 'belittle': 1, 'bring': 1, 'create': 1, 'convince': 3, 'express': 1, 'avoid': 1, 'have': 1, 'steal': 1, 'accuse': 3, 'give': 2, 'resign': 1, 'break': 2, 'block': 1, 'indulge': 1, 'abuse': 1, 'reveal': 2, 'ask': 1, 'meet': 1, 'know': 1, 'fail': 1, 'threaten': 1, 'go': 1, 'kill': 2, 'protect': 2, 'dump': 2, 'jail': 1, 'frame': 1, 'undergo': 1, 'transform': 1, 'adopt': 1, 'leave': 1, 'undertake': 1, 'plan': 1, 'finish': 1, 'decide': 1, 'shock': 1, 'take': 1, 'compose': 24, 'pen': 24}), 'F': defaultdict(<class 'int'>, {'arrive': 1, 'assign': 1, 'be': 2, 'look': 1, 'warn': 1, 'succeed': 1, 'inform': 1, 'arrest': 1, 'belittle': 1, 'try': 1, 'convince': 1, 'express': 1, 'avoid': 1, 'win': 1, 'engage': 1, 'make': 1, 'meet': 1, 'know': 1, 'reveal': 1, 'fool': 1, 'apologize': 1, 'undertake': 1, 'adopt': 1, 'block': 1, 'become': 1, 'compose': 9, 'pen': 9})}
# Accuracy: 0.970590
# Accuracy: 0.970590
# Accuracy: 0.968456
# Accuracy: 0.972047
# Accuracy: 0.968664
# Accuracy: 0.966946
# Accuracy: 0.968716
# Accuracy: 0.968768
# Accuracy: 0.970538
# Accuracy: 0.970225
# Accuracy: 0.969184
# Accuracy: 0.970590
# 27628976
# {'M': defaultdict(<class 'int'>, {'live': 3, 'name': 1, 'know': 4, 'appoint': 1, 'have': 8, 'be': 11, 's': 2, 'consider': 2, 'give': 3, 'get': 3, 'do': 1, 'love': 1, 'attach': 1, 'become': 1, 'want': 2, 'spend': 1, 'join': 2, 'hope': 1, 'marry': 1, 'make': 1, 'save': 2, 'keep': 2, 'kill': 4, 'arrest': 3, 'find': 5, 'hang': 1, 'lodge': 1, 'ask': 1, 'help': 3, 'prove': 3, 'say': 3, 'commit': 2, 'announce': 1, 'rape': 1, 'produce': 1, 'show': 1, 'prefer': 2, 'try': 1, 'frame': 1, 'stick': 1, 'go': 1, 'ensure': 1}), 'F': defaultdict(<class 'int'>, {'consider': 1, 'marry': 1, 's': 1, 'fear': 1, 'manage': 1, 'get': 1, 'rape': 1, 'find': 1, 'kill': 2, 'have': 1})}
# Accuracy: 0.966842
# Accuracy: 0.969184
# Accuracy: 0.969393
# Accuracy: 0.971319
# Accuracy: 0.968404
# Accuracy: 0.969028
# Accuracy: 0.968612
# Accuracy: 0.969861Accuracy: 0.967362
#
# 12973724
# {'M': defaultdict(<class 'int'>, {'marry': 2, 'lose': 1, 'forfeit': 1, 'become': 1, 'hurl': 1, 'escape': 1, 'reunite': 1, 'be': 1}), 'F': defaultdict(<class 'int'>, {'marry': 2, 'wish': 1, 'uncover': 1, 'hurl': 1})}
# Accuracy: 0.970954
# 34296753
# {'M': defaultdict(<class 'int'>, {'be': 1, 'take': 1}), 'F': defaultdict(<class 'int'>, {'be': 5, 'have': 4, 'attract': 1, 'carry': 1, 'decide': 1, 'anger': 1, 'start': 1, 'do': 1, 'want': 1, 'know': 1, 'talk': 1, 'refuse': 2, 'speak': 1, 'remain': 1, 'take': 1})}
# Accuracy: 0.970017
# Accuracy: 0.968612
# Accuracy: 0.971579
# 15705596
# {'M': defaultdict(<class 'int'>, {'be': 1, 'see': 1, 'tell': 1, 'recognize': 1, 'rape': 1}), 'F': defaultdict(<class 'int'>, {'meet': 1, 'attract': 1, 'have': 1, 'involve': 1, 'be': 3, 'believe': 1, 'devastate': 1, 'take': 3, 'rape': 2, 'introduce': 2, 'see': 2, 'recognize': 1})}
# Accuracy: 0.969809
# Accuracy: 0.971423
# Accuracy: 0.968612
# Accuracy: 0.96939335083022
#
# {'M': defaultdict(<class 'int'>, {'be': 5, 'arrest': 2, 'transfer': 1, 'eradicate': 1, 'have': 1, 'suspect': 3, 'take': 1, 'get': 3, 'hate': 1, 'marry': 1, 'lose': 1, 'decide': 3, 'want': 1, 'release': 1, 'revenge': 2, 'kill': 4, 'see': 1, 'escape': 1, 'send': 2}), 'F': defaultdict(<class 'int'>, {'have': 1, 'send': 1, 'see': 1, 'decide': 1, 'protect': 1, 'kidnap': 1})}
# Accuracy: 0.967727
# Accuracy: 0.969340
# Accuracy: 0.969236
# Accuracy: 0.969549
# Accuracy: 0.968456
# Accuracy: 0.969028
# Accuracy: 0.968404
# Accuracy: 0.968664
# 12253731
# {'M': defaultdict(<class 'int'>, {'be': 2, 'infer': 1, 'machinate': 1}), 'F': defaultdict(<class 'int'>, {'be': 3, 'begin': 1, 'manage': 1, 'happen': 1, 'seem': 1, 'embark': 1, 'have': 1, 'descend': 1, 'arrive': 1, 'prove': 1, 'crack': 1, 'spurn': 1, 'achieve': 1, 'machinate': 1, 'get': 1, 'create': 1})}
# Accuracy: 0.971319
# Accuracy: 0.970694
# 20950152
# {'M': defaultdict(<class 'int'>, {'be': 2, 'want': 1, 'marry': 1, 'walk': 1, 'get': 1, 'go': 2, 'meet': 3, 'suspect': 1, 'decide': 1, 'see': 3, 'try': 1, 'disclose': 1, 'avoid': 1, 'take': 1, 'reveal': 1}), 'F': defaultdict(<class 'int'>, {'marry': 2, 'want': 1, 'walk': 1, 'meet': 2, 'learn': 1, 'commit': 1, 'have': 1, 'see': 3, 'send': 1, 'disclose': 1, 'avoid': 1, 'take': 1})}
# 5108489
# {'M': defaultdict(<class 'int'>, {'attract': 1, 'be': 3, 'marry': 1, 'work': 1, 'care': 1, 'get': 1, 'suffer': 1, 'meet': 3, 'lose': 1}), 'F': defaultdict(<class 'int'>, {'become': 1, 'get': 1, 'know': 1, 'prejudge': 1, 'lose': 1})}
# Accuracy: 0.969861
# Accuracy: 0.969080
# Accuracy: 0.968872
# 36057886
# {'M': defaultdict(<class 'int'>, {'be': 1, 'live': 1}), 'F': defaultdict(<class 'int'>, {'live': 2})}
# Accuracy: 0.968091
# Accuracy: 0.970434
# Accuracy: 0.970382
# Accuracy: 0.969757
# 33435792
# {'M': defaultdict(<class 'int'>, {}), 'F': defaultdict(<class 'int'>, {})}
# Accuracy: 0.968924
# Accuracy: 0.969132
# Accuracy: 0.967987
# Accuracy: 0.970850
# Accuracy: 0.970173
# Accuracy: 0.970329
# Accuracy: 0.969184
# Accuracy: 0.969080
# 32191033
# {'M': defaultdict(<class 'int'>, {'be': 1}), 'F': defaultdict(<class 'int'>, {})}
# 29480522
# {'M': defaultdict(<class 'int'>, {'be': 1, 'love': 1}), 'F': defaultdict(<class 'int'>, {})}
# 4071411
# {'M': defaultdict(<class 'int'>, {}), 'F': defaultdict(<class 'int'>, {})}
# Accuracy: 0.969028
# Accuracy: 0.969288
# 13705136
# {'M': defaultdict(<class 'int'>, {'be': 1, 'rebuke': 1, 'marry': 1}), 'F': defaultdict(<class 'int'>, {'belong': 2, 'fall': 2, 'rebuke': 1, 'leave': 2, 'humiliate': 1, 'return': 1, 'be': 3, 'raise': 2, 'grow': 3, 'go': 1, 'marry': 1, 'move': 1, 'create': 1, 'remind': 1, 'add': 1, 'miss': 1, 'beg': 1, 'reunite': 3})}
# Accuracy: 0.968924
# 33743708
# {'M': defaultdict(<class 'int'>, {'lead': 1, 'appear': 2, 'eat': 1, 'give': 1, 'be': 2, 'discover': 1, 'inform': 3, 'lock': 1, 'visit': 1, 'need': 2, 'make': 1, 'lie': 1, 'stone': 1, 'order': 1, 'imprison': 2, 'have': 2, 'confine': 1, 'realize': 1}), 'F': defaultdict(<class 'int'>, {'visit': 3, 'inform': 2, 'have': 2, 'lock': 1, 'confine': 1, 'tell': 1, 'put': 1, 'go': 1})}
# Accuracy: 0.967779
# Accuracy: 0.972568
# Accuracy: 0.969080
# Accuracy: 0.969236
# Accuracy: 0.968820
# Accuracy: 0.967675
# Accuracy: 0.969132
# Accuracy: 0.970486
# Accuracy: 0.969809
# Accuracy: 0.968976
# Accuracy: 0.971319
# Accuracy: 0.971579
# 14538051
# {'M': defaultdict(<class 'int'>, {'name': 1, 'complete': 1, 'have': 4, 'indulge': 1, 'marry': 2, 'be': 5, 'want': 2, 'annul': 2, 'fall': 1, 'do': 1, 'meet': 2, 'decide': 1, 'agree': 1, 'seem': 1, 'start': 2, 'feel': 1, 'turn': 2, 'arrive': 2, 'confess': 1, 'change': 1, 'continue': 1, 'pursue': 1, 'leave': 1, 'care': 1, 'follow': 1, 'attempt': 3, 'escape': 1, 'kill': 1, 'fire': 1, 'reach': 1, 'lure': 1, 'confront': 1, 'accuse': 1, 'pierce': 1, 'attack': 2, 'take': 1, 'treat': 1, 'deliver': 2}), 'F': defaultdict(<class 'int'>, {'be': 3, 'quit': 1, 'marry': 1, 'refuse': 1, 'hear': 2, 'have': 1, 'reconsider': 1, 'ask': 1, 'provide': 1, 'go': 2, 'meet': 2, 'look': 1, 'find': 1, 'get': 1, 'support': 1, 'turn': 1, 'disagree': 1, 'shatter': 1, 'pursue': 1, 'show': 1, 'care': 1, 'learn': 1, 'accuse': 1, 'run': 1, 'slip': 1, 'take': 1, 'deliver': 1})}
# 25802262
# {'M': defaultdict(<class 'int'>, {}), 'F': defaultdict(<class 'int'>, {})}
# Accuracy: 0.968976
# Accuracy: 0.968612
# Accuracy: 0.968716
# Accuracy: 0.969549
# Accuracy: 0.967362
# 26067636
# {'M': defaultdict(<class 'int'>, {'start': 1, 'disappear': 1, 'narrate': 2, 'name': 3, 'rescue': 1, 'be': 13, 'give': 2, 'inform': 1, 'hunt': 1, 'scold': 2, 'come': 1, 'defend': 1, 'raise': 1, 'end': 2, 'have': 8, 'fight': 3, 'pick': 1, 'obtain': 1, 'claim': 1, 'belong': 1, 'find': 7, 'get': 1, 'instruct': 1, 'try': 5, 'pursue': 2, 'point': 2, 'tell': 22, 'arrive': 2, 'defeat': 2, 'go': 3, 'return': 3, 'take': 2, 'learn': 1, 'show': 1, 'capture': 2, 'force': 1, 'work': 1, 'free': 2, 'enlist': 3, 'help': 1, 'await': 1, 'prevent': 2, 'shoot': 2, 'contain': 1, 'run': 1, 'reach': 1, 'do': 2, 'make': 3, 'heal': 3, 'enter': 1, 'leave': 6, 'recite': 1, 'receive': 1, 'fire': 1, 'devour': 1, 'state': 2, 'deserve': 2, 'turn': 2, 'harm': 1, 'hide': 1, 'prepare': 1, 'consider': 2, 'reunite': 1, 'place': 1, 'mention': 1}), 'F': defaultdict(<class 'int'>, {'pick': 1, 'have': 1, 'instruct': 1, 'tell': 2, 'find': 1, 'take': 1, 'involve': 1, 'become': 1, 'capture': 1, 'free': 2, 'help': 1, 'recite': 1, 'deserve': 1, 'harm': 1, 'understand': 1, 'leave': 1, 'come': 1})}
# Accuracy: 0.971891
# Accuracy: 0.969288
# Accuracy: 0.971214
# Accuracy: 0.968508
# 2241614
# {'M': defaultdict(<class 'int'>, {'be': 4, 'come': 1, 'introduce': 1, 'call': 2, 'attend': 2, 'meet': 2, 'fall': 1, 'imprison': 1, 'kill': 3, 'acknowledge': 2, 'agree': 1, 'die': 1}), 'F': defaultdict(<class 'int'>, {'hope': 1, 'marry': 1, 'testify': 1, 'agree': 3, 'hire': 1, 'kill': 2, 'acknowledge': 1, 'learn': 2, 'go': 1, 'save': 1, 'unite': 1})}19289204
#
# {'M': defaultdict(<class 'int'>, {'be': 5, 'live': 2, 'join': 2, 'allow': 2, 'prohibit': 2, 'come': 2, 'take': 1, 'arrive': 1, 'vacate': 2, 'find': 1, 'make': 3, 'force': 1, 'disguise': 1, 'marry': 1, 'fall': 1}), 'F': defaultdict(<class 'int'>, {'live': 1, 'appease': 1, 'upset': 1, 'absolve': 1, 'set': 1})}Accuracy: 0.967258
#
# Accuracy: 0.968664Accuracy: 0.970434
# 6954675
#
# {'M': defaultdict(<class 'int'>, {'be': 1, 'vow': 1, 'kill': 1}), 'F': defaultdict(<class 'int'>, {'be': 1})}
# Accuracy: 0.970382
# Accuracy: 0.969080
# Accuracy: 0.969601
# Accuracy: 0.969549
# 16861768
# {'M': defaultdict(<class 'int'>, {'need': 1, 'do': 1, 'recruit': 2, 'kill': 1, 'get': 2, 'ensure': 1, 'be': 1, 'abduct': 1, 'give': 1}), 'F': defaultdict(<class 'int'>, {'be': 1, 'like': 1, 'abduct': 1})}
# Accuracy: 0.969340
# Accuracy: 0.970069
# Accuracy: 0.969965
# Accuracy: 0.968716
# 31100425
# 5995771{'M': defaultdict(<class 'int'>, {'have': 2, 'put': 1, 'enter': 1, 'name': 2, 'help': 1}), 'F': defaultdict(<class 'int'>, {'concern': 1, 'paralyze': 2, 'lead': 1, 'marry': 1, 'get': 1, 'discover': 1, 'be': 1})}
#
# {'M': defaultdict(<class 'int'>, {'complete': 1, 'kidnap': 1, 'be': 1, 'harass': 1, 'find': 1, 'become': 1, 'leave': 1, 'decide': 1, 'go': 1, 'get': 1, 'ask': 1, 'stay': 2, 'fall': 1}), 'F': defaultdict(<class 'int'>, {'take': 1, 'find': 1, 'get': 1, 'stay': 1})}
# Accuracy: 0.969861
# Accuracy: 0.967519
# Accuracy: 0.968612
# Accuracy: 0.969080
# 190158563011301
#
# {'M': defaultdict(<class 'int'>, {'return': 1, 'find': 1, 'fill': 1, 'tell': 1, 'force': 1, 'have': 1, 'reject': 1, 'decide': 1, 'punish': 1, 'stand': 1, 'catch': 2, 'happen': 1}), 'F': defaultdict(<class 'int'>, {'know': 1})}{'M': defaultdict(<class 'int'>, {'open': 3, 'awake': 1, 'get': 1, 'scream': 1, 'keep': 1, 's': 1, 'kill': 2, 'hold': 1, 'be': 5, 'love': 1, 'wish': 1, 'impress': 2, 'decide': 1, 'buy': 1, 'instruct': 2, 'woo': 2, 'reach': 1, 'go': 2, 'remain': 1, 'lure': 2, 'hatch': 1, 'become': 1, 'lock': 1, 'leave': 1, 'die': 1, 'agree': 1, 'wed': 1, 'recover': 1, 'hear': 2, 'appear': 2, 'stop': 2, 'lead': 1, 'tell': 2, 'release': 1, 'run': 1, 'discover': 1}), 'F': defaultdict(<class 'int'>, {'kill': 3, 'get': 2, 'appear': 1, 'come': 2, 'be': 5, 'wish': 2, 'milk': 2, 'love': 1, 'impress': 1, 'approve': 1, 'do': 1, 'woo': 1, 'ask': 1, 'send': 1, 'reach': 1, 'hatch': 1, 'lure': 2, 'agree': 1, 'wed': 1, 'stay': 1})}
#
# Accuracy: 0.968664
# Accuracy: 0.969913
# Accuracy: 0.970225
# 30864791
# {'M': defaultdict(<class 'int'>, {'be': 1, 'enter': 1, 'fall': 2, 'succeed': 1, 'leave': 2, 'return': 1, 'meet': 1, 'become': 1, 'come': 1}), 'F': defaultdict(<class 'int'>, {'be': 2, 'express': 1, 'leave': 2, 'return': 1})}
# 25940830
# {'M': defaultdict(<class 'int'>, {}), 'F': defaultdict(<class 'int'>, {})}
# Accuracy: 0.968039
# Accuracy: 0.970173
# 25901276Accuracy: 0.970954
#
# {'M': defaultdict(<class 'int'>, {'find': 1, 'be': 3}), 'F': defaultdict(<class 'int'>, {})}
# Accuracy: 0.969965
# Accuracy: 0.968247
# Accuracy: 0.968872
# 24064110
# {'M': defaultdict(<class 'int'>, {'recruit': 1, 'come': 1, 'hospitalize': 1, 'assign': 2, 'be': 2, 'apprehend': 1, 'find': 2, 'die': 1, 'concocte': 1, 'do': 3, 'know': 1, 'swear': 1}), 'F': defaultdict(<class 'int'>, {'run': 1, 'love': 1, 'tell': 1, 'take': 1, 'attract': 1, 'be': 2, 'rescue': 2, 'believe': 1})}
# Accuracy: 0.968612
# 25381381
# {'M': defaultdict(<class 'int'>, {'appoint': 1, 'want': 1, 'marry': 1, 'meet': 1, 'send': 1, 'capture': 1, 'produce': 1, 'demand': 1, 'decide': 1, 'kill': 2, 'beg': 1, 'push': 1}), 'F': defaultdict(<class 'int'>, {'go': 1, 'meet': 2, 'blame': 1, 'kill': 2, 'tell': 1, 'beg': 1, 'push': 1, 'confess': 1, 'shock': 1})}
# Accuracy: 0.969028
# Accuracy: 0.970538
# Accuracy: 0.971735
# Accuracy: 0.970382
# Accuracy: 0.968976
# Accuracy: 0.970069
# Accuracy: 0.968351
# Accuracy: 0.967154
# Accuracy: 0.967467
# 5747371Accuracy: 0.969393
#
# {'M': defaultdict(<class 'int'>, {'find': 1, 'be': 1, 'turn': 2, 'kill': 1, 'grow': 1}), 'F': defaultdict(<class 'int'>, {'be': 2, 'marry': 2, 'dress': 1, 'slip': 1, 'meet': 1, 'find': 1})}
# Accuracy: 0.968924
# Accuracy: 0.968351
# Accuracy: 0.972151
# 5522723
# {'M': defaultdict(<class 'int'>, {'drive': 1, 'undergo': 1, 'meet': 2, 'be': 3, 'take': 3, 'carry': 2, 'beat': 1, 'upset': 1, 'ask': 2, 'sing': 1, 'travel': 1, 'pass': 1, 'tell': 1, 's': 1, 'see': 3, 'join': 2, 'reach': 1, 'stay': 1, 'attend': 2, 'become': 1, 'disturb': 1, 'try': 1, 'shield': 1, 'involve': 1, 'get': 1, 'understand': 1, 'leave': 2, 'reveal': 1}), 'F': defaultdict(<class 'int'>, {'carry': 1, 'mesmerize': 1, 'progress': 1, 'be': 2, 'see': 3, 'join': 1, 'ask': 1, 'stay': 1, 'arrange': 1, 'disturb': 1, 'shield': 1, 'protect': 1, 'try': 1, 'make': 1, 'leave': 2, 'start': 1, 'refuse': 1, 'understand': 1, 'meet': 1, 'reveal': 1, 'sell': 1})}
# Accuracy: 0.969340
# Accuracy: 0.968404
# Accuracy: 0.969497
# Accuracy: 0.971423
# Accuracy: 0.968039
# Accuracy: 0.970486
# 4510764
# {'M': defaultdict(<class 'int'>, {'help': 5, 'impress': 1, 'be': 2, 'express': 1, 'reject': 1, 'try': 1, 'commit': 1, 'save': 1, 'know': 1, 'marry': 2, 's': 1, 'oppose': 1, 'hit': 1, 'suspect': 1, 'spread': 1, 'decide': 1, 'ask': 2, 'insult': 1, 'leave': 1, 'go': 1, 'accept': 1, 'apologise': 1, 'unite': 1}), 'F': defaultdict(<class 'int'>, {'woo': 1, 'accept': 2, 'leave': 3, 'seek': 2, 'see': 1, 'plan': 1, 'try': 1, 'marry': 3, 'write': 1, 'take': 2, 'save': 2, 'bring': 1, 'insult': 1})}
# Accuracy: 0.969340
# Accuracy: 0.968664
# Accuracy: 0.969497
# 10592638
# {'M': defaultdict(<class 'int'>, {'be': 2}), 'F': defaultdict(<class 'int'>, {'be': 1, 'discover': 1, 'name': 1, 'alia': 2})}
# Accuracy: 0.969757
# 35372452Accuracy: 0.968560
# {'M': defaultdict(<class 'int'>, {}), 'F': defaultdict(<class 'int'>, {'have': 1})}
# 10776705
# {'M': defaultdict(<class 'int'>, {'widow': 1, 'have': 1, 'live': 1, 'be': 1, 'ask': 2, 'say': 2, 'want': 2, 'see': 2, 'go': 1, 'get': 1, 'return': 1, 'tell': 1, 'marry': 2, 'come': 5, 'refuse': 1, 'miss': 1, 'visit': 2, 'do': 1, 'accompany': 1, 'promise': 1}), 'F': defaultdict(<class 'int'>, {'have': 3, 'marry': 4, 'live': 1, 'ask': 1, 'say': 1, 'see': 2, 'agree': 1, 'take': 1, 'educate': 1, 'understand': 1, 'come': 2, 'refuse': 3, 'handle': 1, 'stay': 1, 'leave': 3, 'head': 1, 'start': 1, 'miss': 1, 'realize': 2, 'tell': 2, 'want': 3, 'go': 2, 'excel': 1, 'bruise': 1, 'accompany': 1, 'write': 1, 'do': 1, 'get': 1, 'be': 1})}
# Accuracy: 0.969601
# Accuracy: 0.969184
# Accuracy: 0.969861
# Accuracy: 0.971058
# 15041008

# %%
x1 = result

# %%
## Save frequency
import pickle
output = open('india_before_2000_adj.pkl', 'wb')
pickle.dump(frequency_list, output)
output.close()

# %%
import pickle
pkl_file = open('india_before_2000.pkl', 'rb')

frequency_list = pickle.load(pkl_file)

# %%
# Combine frequency from different results
frequency_list = {'M':defaultdict(int),'F':defaultdict(int)}

for freq in result:
    if freq is None:
        continue
    for k, v in freq['M'].items():
        frequency_list['M'][k]+=v
    for k, v in freq['F'].items():
        frequency_list['F'][k]+=v

# %% [markdown]
# # Calculate Odds Ratio

# %%
odds_ratio = {}
threshold  = 2
topk       = 50

total_num_f = sum(frequency_list['F'].values())
total_num_m = sum(frequency_list['M'].values())

for key in frequency_list['F'].keys():
    m_num = frequency_list['M'][key]
    f_num = frequency_list['F'][key]
    non_f_num = total_num_f - f_num
    non_m_num = total_num_m - m_num
    if f_num >= threshold and m_num >= threshold:
        # we only consider the events where there are at least {thresohld} occurences for both gender
        odds_ratio[key] = round((m_num / f_num) / (non_m_num / non_f_num), 2)
    else:
        continue

# %%
from operator import itemgetter

top_m = dict(sorted(odds_ratio.items(), key=itemgetter(1), reverse=True)[:topk])
top_f = dict(sorted(odds_ratio.items(), key=itemgetter(1))[:topk])

# %% [markdown]
# ### Before 2000 - India

# %%
top_m, top_f
# Out:
# ({'male': 5.98,
#   'major': 5.15,
#   'proud': 3.76,
#   'honest': 3.66,
#   'powerful': 3.48,
#   'look-alike': 3.31,
#   'close': 3.27,
#   'alcoholic': 3.1,
#   'criminal': 2.88,
#   'guilty': 2.72,
#   'terrorist': 2.65,
#   'entire': 2.65,
#   'eccentric': 2.65,
#   'disappointed': 2.65,
#   'future': 2.65,
#   'few': 2.65,
#   'late': 2.59,
#   'maternal': 2.51,
#   'blind': 2.42,
#   'unemployed': 2.39,
#   'native': 2.32,
#   'confident': 2.32,
#   'suspicious': 2.32,
#   'full': 2.32,
#   'gifted': 2.32,
#   'superior': 2.21,
#   'secret': 2.21,
#   'disabled': 2.21,
#   'rival': 2.21,
#   'evil': 2.05,
#   'first': 2.03,
#   'responsible': 1.99,
#   'dark': 1.99,
#   'long-lost': 1.99,
#   'shy': 1.99,
#   'romantic': 1.99,
#   'chief': 1.99,
#   'black': 1.99,
#   'principal': 1.99,
#   'public': 1.99,
#   'rid': 1.99,
#   'successful': 1.95,
#   'wealthy': 1.89,
#   'frustrated': 1.86,
#   'bad': 1.82,
#   'holy': 1.82,
#   'willing': 1.77,
#   'deceased': 1.77,
#   'injured': 1.77,
#   'good': 1.74},
#  {'female': 0.05,
#   'beautiful': 0.09,
#   'lovely': 0.12,
#   'tribal': 0.15,
#   'christian': 0.17,
#   'reborn': 0.19,
#   'traditional': 0.19,
#   'grand': 0.2,
#   'pregnant': 0.2,
#   'small-time': 0.22,
#   'dumb': 0.22,
#   'unmarried': 0.24,
#   'attractive': 0.24,
#   'back': 0.26,
#   'intelligent': 0.26,
#   'special': 0.26,
#   'destitute': 0.26,
#   'separated': 0.26,
#   'pampered': 0.26,
#   'miserable': 0.26,
#   'ill': 0.29,
#   'married': 0.31,
#   'hungry': 0.33,
#   'teenage': 0.33,
#   'multi-millionaire': 0.33,
#   'penniless': 0.33,
#   'anglo-indian': 0.33,
#   'well-educated': 0.33,
#   'orphan': 0.33,
#   'conservative': 0.33,
#   'several': 0.33,
#   'charming': 0.33,
#   'silent': 0.33,
#   'grown': 0.33,
#   'clever': 0.33,
#   'untouchable': 0.33,
#   'heartbroken': 0.35,
#   'single': 0.37,
#   'sick': 0.39,
#   'emotional': 0.4,
#   'heart-broken': 0.4,
#   'separate': 0.4,
#   'punjabi': 0.4,
#   'supportive': 0.4,
#   'distressed': 0.4,
#   'adamant': 0.41,
#   'same': 0.43,
#   'uneducated': 0.44,
#   'e-mail': 0.44,
#   'tragic': 0.44})

# %% [markdown]
# ### After 2000 - India

# %%
top_m, top_f
# Out:
# ({'senior': 5.49,
#   'defeat': 5.17,
#   'shoot': 4.6,
#   'provide': 4.52,
#   'encounter': 3.87,
#   'successful': 3.87,
#   'succeed': 3.55,
#   'capture': 3.55,
#   'set': 3.52,
#   'suspect': 3.44,
#   'finish': 3.44,
#   'old': 3.06,
#   'transform': 3.01,
#   'prove': 2.91,
#   'overcome': 2.9,
#   'track': 2.9,
#   'greet': 2.9,
#   'perceive': 2.9,
#   'terrorist': 2.8,
#   'ready': 2.8,
#   'arrest': 2.76,
#   'transfer': 2.74,
#   'eliminate': 2.71,
#   'visit': 2.66,
#   'responsible': 2.58,
#   'remove': 2.58,
#   'drunk': 2.58,
#   'sure': 2.58,
#   'pick': 2.58,
#   'entire': 2.58,
#   'good': 2.49,
#   'avenge': 2.42,
#   'separate': 2.42,
#   'injure': 2.42,
#   'due': 2.42,
#   'wrong': 2.37,
#   'fight': 2.37,
#   'last': 2.32,
#   'continue': 2.3,
#   'beat': 2.28,
#   'create': 2.26,
#   'local': 2.26,
#   'free': 2.26,
#   'demand': 2.26,
#   'unknown': 2.26,
#   'study': 2.26,
#   'develop': 2.19,
#   'earn': 2.15,
#   'trust': 2.15,
#   'insult': 2.1},
#  {'beautiful': 0.09,
#   'female': 0.11,
#   'remind': 0.14,
#   'surprise': 0.16,
#   'represent': 0.21,
#   'pregnant': 0.23,
#   'upset': 0.24,
#   'advise': 0.25,
#   'deliver': 0.26,
#   'test': 0.26,
#   'deceive': 0.26,
#   'long': 0.26,
#   'dump': 0.26,
#   'biological': 0.28,
#   'ill': 0.29,
#   'elope': 0.29,
#   'teach': 0.3,
#   'identify': 0.32,
#   'stab': 0.32,
#   'answer': 0.32,
#   'step': 0.32,
#   'mention': 0.32,
#   'undergo': 0.32,
#   'tie': 0.32,
#   'teenage': 0.32,
#   'shocked': 0.32,
#   'assume': 0.36,
#   'miss': 0.36,
#   'devastate': 0.38,
#   'abandon': 0.39,
#   'harass': 0.39,
#   'faint': 0.39,
#   'rape': 0.41,
#   'operate': 0.43,
#   'previous': 0.43,
#   'estrange': 0.43,
#   'trace': 0.43,
#   'secret': 0.43,
#   'social': 0.43,
#   'scream': 0.43,
#   'single': 0.43,
#   'confirm': 0.43,
#   'brilliant': 0.43,
#   're-unite': 0.43,
#   'prevent': 0.43,
#   'reform': 0.43,
#   'loathe': 0.43,
#   'link': 0.43,
#   'cross': 0.43,
#   'beg': 0.45})

# %% [markdown]
# # Weat Score Calculation

# %%
def swAB(W, A, B):
    """Calculates differential cosine-similarity between word vectors in W, A and W, B
     Arguments
              W, A, B : n x d matrix of word embeddings stored row wise
    """
    WA = cosine_similarity(W,A)
    WB = cosine_similarity(W,B)

    #Take mean along columns
    WAmean = np.mean(WA, axis = 1)
    WBmean = np.mean(WB, axis = 1)

    return (WAmean - WBmean)
  
def test_statistic(X, Y, A, B):
    """Calculates test-statistic between the pair of association words and target words
     Arguments
              X, Y, A, B : n x d matrix of word embeddings stored row wise
     Returns
              Test Statistic
    """
    return (sum(swAB(X, A, B)) - sum(swAB(Y, A, B)))

# %%
def weat_effect_size(X, Y, A, B, embd):
    """Computes the effect size for the given list of association and target word pairs
     Arguments
              X, Y : List of association words
              A, B : List of target words
              embd : Dictonary of word-to-embedding for all words
     Returns
              Effect Size
    """

    Xmat = np.array([embd[w.lower()] for w in X if w.lower() in embd])
    Ymat = np.array([embd[w.lower()] for w in Y if w.lower() in embd])
    Amat = np.array([embd[w.lower()] for w in A if w.lower() in embd])
    Bmat = np.array([embd[w.lower()] for w in B if w.lower() in embd])

    XuY = list(set(X).union(Y))
    XuYmat = []
    for w in XuY:
        if w.lower() in embd:
            XuYmat.append(embd[w.lower()])
    XuYmat = np.array(XuYmat)


    d = (np.mean(swAB(Xmat,Amat,Bmat)) - np.mean(swAB(Ymat,Amat,Bmat)))/np.std(swAB(XuYmat, Amat, Bmat))

    return d

# %%
def random_permutation(iterable, r=None):
    """Returns a random permutation for any iterable object"""
    pool = tuple(iterable)
    r = len(pool) if r is None else r
    return tuple(random.sample(pool, r))

def weat_p_value(X, Y, A, B, embd, sample = 1000):
    """Computes the one-sided P value for the given list of association and target word pairs
     Arguments
              X, Y : List of association words
              A, B : List of target words
              embd : Dictonary of word-to-embedding for all words
              sample : Number of random permutations used.
     Returns
    """
    size_of_permutation = min(len(X), len(Y))
    X_Y = X + Y
    test_stats_over_permutation = []

    Xmat = np.array([embd[w.lower()] for w in X if w.lower() in embd])
    Ymat = np.array([embd[w.lower()] for w in Y if w.lower() in embd])
    Amat = np.array([embd[w.lower()] for w in A if w.lower() in embd])
    Bmat = np.array([embd[w.lower()] for w in B if w.lower() in embd])

    if not sample:
        permutations = combinations(X_Y, size_of_permutation)
    else:
        permutations = [random_permutation(X_Y, size_of_permutation) for s in range(sample)]

    for Xi in permutations:
        Yi = filterfalse(lambda w:w in Xi, X_Y)
        Ximat = np.array([embd[w.lower()] for w in Xi if w.lower() in embd])
        Yimat = np.array([embd[w.lower()] for w in Yi if w.lower() in embd])
        test_stats_over_permutation.append(test_statistic(Ximat, Yimat, Amat, Bmat))

    unperturbed = test_statistic(Xmat, Ymat, Amat, Bmat)
  
    is_over = np.array([o > unperturbed for o in test_stats_over_permutation])
  
    return is_over.sum() / is_over.size

# %%
"""List of association and target word pairs for the sample test (top_m, top_f) vs (Pleasant, Unpleasant)"""


X = list(top_m.keys())

Y = list(top_f.keys())

# Find better pleasant and unpleasant words

A = ["caress", "freedom", "health", "love", "peace", "cheer", "friend", "heaven", "loyal", "pleasure", "diamond", "gentle", "honest", "lucky", "rainbow", "diploma", "gift", "honor", "miracle", "sunrise", "family",
    "happy", "laughter", "paradise", "vacation"] 

B = ["abuse", "crash", "filth", "murder", "sickness", "accident", "death", "grief", "poison", "stink", "assault", "disaster", "hatred", "pollute", "tragedy", "divorce", "jail", "poverty", "ugly", "cancer", "kill", "rotten",
    "vomit", "agony", "prison"] 


resourceFile = ''
glove = KeyedVectors.load_word2vec_format('embeddings/GoogleNews-vectors-negative300.bin', binary=True)
print('The glove embedding has been loaded!')

"""Compute the effect-size and P value"""
print('WEAT d = ', weat_effect_size(X, Y, A, B, glove))
print('WEAT p = ', weat_p_value(X, Y, A, B, glove, 1000))
# Out:
# The glove embedding has been loaded!
# WEAT d =  -0.3398966
# WEAT p =  0.969

# %%
import numpy as np
from gensim.models import KeyedVectors
import gensim
import random
import sys
import glob
import os
import json
from gensim.models import Word2Vec
from scipy import stats
import sys
import math

def word_assoc(w,A,B,embedding):
    """
    Calculates difference in mean cosine similarity between a word and two sets
    of words.
    """
    return embedding.n_similarity([w],A) - embedding.n_similarity([w],B)

def diff_assoc(X,Y,A,B,embedding):
    """
    Caclulates the WEAT test statics for four sets of words in an embeddings
    """
    word_assoc_X = np.array(list(map(lambda x : word_assoc(x,A,B,embedding), X)))
    word_assoc_Y = np.array(list(map(lambda y : word_assoc(y,A,B,embedding), Y)))
    mean_diff = np.mean(word_assoc_X) - np.mean(word_assoc_Y)
    std = np.std(np.concatenate((word_assoc_X, word_assoc_Y), axis=0))
    return mean_diff / std

def get_bias_scores_mean_err(word_pairs,embedding):
    """
    Caculate the mean WEAT statistic and standard error using a permutation test
    on the sets of words (defaults to 100 samples)
    """
    # divide smaller word_list by two
    subset_size_target = min(len(word_pairs['X']),len(word_pairs['Y']))//2
    subset_size_attr = min(len(word_pairs['A']),len(word_pairs['B']))//2
    bias_scores = []
    for i in range(100):
        sX = np.random.choice(word_pairs['X'],subset_size_target,replace=False)
        sY = np.random.choice(word_pairs['Y'],subset_size_target,replace=False)
        sA = np.random.choice(word_pairs['A'],subset_size_attr,replace=False)
        sB = np.random.choice(word_pairs['B'],subset_size_attr,replace=False)
        bias_scores.append(diff_assoc(sX,sY,sA,sB,embedding))
    return np.mean(bias_scores), stats.sem(bias_scores)


def run_test(config, embedding):
    word_pairs = {}
    min_len = sys.maxsize
    # Only include words that are present in the word embedding
    for word_list_name, word_list in config.items():
        if word_list_name in ['X', 'Y', 'A', 'B']:
            word_list_filtered = list(filter(lambda x: x in embedding and np.count_nonzero(embedding[x]) > 0, word_list))
            word_pairs[word_list_name] = word_list_filtered
            if len(word_list_filtered) < 2:
                print('ERROR: Words from list {} not found in embedding\n {}'.\
                format(word_list_name, word_list))
                print('All word groups must contain at least two words')
                return None, None
    return get_bias_scores_mean_err(word_pairs,embedding)

def load_embedding(embed_path):
    if embed_path.endswith('wv'):
        return KeyedVectors.load(embed_path)
    elif embed_path.endswith('txt'):
        return KeyedVectors.load_word2vec_format(embed_path, binary=False)
    elif embed_path.endswith('bin'):
        return KeyedVectors.load_word2vec_format(embed_path, binary=True)
    # NOTE reddit embedding is saved as model (no ext) + syn1neg + syn0
    else:
        return Word2Vec.load(embed_path)

# %%
results = {}
embedding = load_embedding('embeddings/GoogleNews-vectors-negative300.bin')
        except:
            print('could not load embedding {}'.format(e_name))
            continue;
        for name_of_test, test_config in config['tests'].items():
            mean, err = run_test(test_config, embedding)
            print('mean: {} err: {}'.format(mean, err))
            if mean is not None:
                results[e_name][name_of_test] = (round(mean, 4), round(err,4))
    else:
        print('loading time series embeddings...')
        for time, embed_path in e.items():
            results[e_name][time] = {}
            embedding = load_embedding(embed_path)
            for name_of_test, test_config in config['tests'].items():
                print(name_of_test)
                mean, err = run_test(test_config, embedding)
                print('mean: {} err: {}'.format(mean, err))
                if mean is not None:
                    results[e_name][time][name_of_test] = (round(mean, 4), round(err,4))
